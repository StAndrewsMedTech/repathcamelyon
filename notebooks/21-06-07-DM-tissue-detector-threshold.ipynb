# %% [markdown]
# # Optimising for low false negatives in tissue detector

# %%
# determinism preamble
from repath.utils.seeds import set_seed

global_seed = 123
set_seed(global_seed)

# %%
# paths preamble
from repath.utils.paths import project_root
experiment_root = project_root() / "experiments" / "tissue" / "low_fp"
experiment_root.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Our objective is to change the parameters and method of the background removal code so that it minimises false negatives. In otherwords it's unlikely to eliminate tissue that might be important.

# %%
# first let's load in the dataset
from repath.data.datasets.tissue import tissue

tissue_dataset = tissue()
tissue_dataset.paths

# %% [markdown]
# Let's take a look at one of these slides with the annotations rendered on it

# %%
# we need some utility function first
from repath.utils.geometry import Size
from repath.utils.convert import to_frame_with_locations, np_to_pil

labels_level = 5
labels = {"background": 0, "tissue": 1}

def dimensions_at_level(level, slide):
    if level >= len(slide.dimensions):
        request_level = len(slide.dimensions) - 1
        lev_diff = level - request_level
        max_level_dim = slide.dimensions[-1]
        requested_level_size = Size(max_level_dim.width // 2 ** lev_diff, max_level_dim.height // 2 ** lev_diff)
        labels_shape = requested_level_size.as_shape()
    else:
        labels_shape = slide.dimensions[level].as_shape()
    return labels_shape

def label_patches(slide_path, annotation_path, label, tags):
    # work out the size of the labels image
    with tissue_dataset.slide_cls(slide_path) as slide:
        labels_shape = dimensions_at_level(labels_level, slide)

    # render the annotations into the labels image
    annotations = tissue_dataset.load_annotations(annotation_path)
    scale_factor = 2 ** labels_level
    labels_array = annotations.render(labels_shape, scale_factor)
    
    return labels_array
    
def as_frame(labels_array, replace_labels=False):
    # change the image into a pandas frame with the labels
    frame = to_frame_with_locations(labels_array, "label")
    if replace_labels:
        frame['label'] = frame['label'].replace( {v: k for k, v in labels.items()})
    
    return frame

def as_image(labels_array):
    return np_to_pil(labels_array)

# %%
import matplotlib.pyplot as plt
import matplotlib

slide_path, annotation_path, label, tags = tissue_dataset[0]

# create the thumbnail of the slide at level 5
with tissue_dataset.slide_cls(slide_path) as slide:
    thumbnail = slide.get_thumbnail(labels_level)
#print(thumbnail.shape)
#thumb_img = np_to_pil(thumbnail)

# create the labels image
labels_array = label_patches(slide_path, annotation_path, label, tags)
# 

print(labels_array.shape)
# labels_img = np_to_pil(labels_array)
# labels_img

cmap = matplotlib.colors.ListedColormap(["white", "yellow"])
plt.figure(figsize=(32,24))
plt.imshow(thumbnail)
plt.imshow(labels_array, alpha=0.5, cmap=cmap)
plt.axis('off')
plt.show()

# %% [markdown]
# Create a list of pandas frames with the labels for each patch. The labels can be background or tissue. We are going to do this at level 5.

# %%
from repath.utils.geometry import Size
from repath.utils.convert import to_frame_with_locations

patches_df_human_labels = [as_frame(label_patches(*s)) for s in tissue_dataset]

# %% [markdown]
# Next, we want to run a bunch of different tissue detectors at level 5 and compare their results to these patches.

# %%
from repath.preprocess.tissue_detection import *
from sklearn.metrics import confusion_matrix, plot_confusion_matrix

def label_with_background_subtractor(subtractor, slide_path, annotation_path, label, tags):
    # load in the slide
    with tissue_dataset.slide_cls(slide_path) as slide:
        # pass the level 5 thumbnail into the background subtractor
        thumbnail = slide.get_thumbnail(5)
    labels_array = subtractor(thumbnail)
    return labels_array

def compute_results(df_computer_labels, slide_idx):
    # compate the two sets of labels
    y_true = patches_df_human_labels[slide_idx]['label'].to_numpy()
    y_pred = df_computer_labels['label'].to_numpy().astype('int')
    return y_true, y_pred
        
detectors = [TissueDetectorOTSU(), TissueDetectorGreyScale()]  
        
def test_subtractor(subtractor):
    # do the test
    patches_df_computer_labels = [as_frame(label_with_background_subtractor(subtractor, *s)) for s in tissue_dataset]
    results = [compute_results(df, idx) for idx, df in enumerate(patches_df_computer_labels)]
    y_true, y_pred = list(zip(*results))
    y_true, y_pred = np.concatenate(y_true), np.concatenate(y_pred)
    
    # compute the metrics
    results = (y_true, y_pred)
    return results

results = [test_subtractor(detector) for detector in detectors]

# %%
from repath.preprocess.tissue_detection.tissue_metrics import calc_tissue_conf_mat, get_output_images, write_contours_to_file

# %% [markdown]
# So now for each detector, we have a list of confusion matrices (ndarrays), one for each slide. To get an idea of the overall false negative rate, let's concatanate all the results and create one big confusion matrix for each detector. Then we can pull out the false negative rate and use that as an optimisation metric.

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt     

def metrics(y_true, y_pred):
    CM = confusion_matrix(y_true, y_pred)
    
    # invert the positive and negative cases because we are using a binary classifier
    CM = CM[[1,0],:]
    CM = CM[:, [1,0]]
    
    print(CM)
    
    TP = CM[0][0]
    FP = CM[1][0]
    TN = CM[1][1]
    FN = CM[0][1]

    # False negative rate
    FNR = FN/(TP+FN)

    # Overall accuracy
    ACC = (TP+TN)/(TP+FP+FN+TN)
    
    return CM, ACC, FNR

all_metrics = [metrics(*res) for idx, res in enumerate(results)]
all_metrics

# %%
from repath.utils.metrics import conf_mat_plot_heatmap

results_df = pd.DataFrame(columns=['detector', 'accuracy', 'false negative rate'])

for idx, (cm, acc, fnc) in enumerate(all_metrics):
    ls = [type(detectors[idx]).__name__, acc, fnc]
    row = pd.Series(ls, index=results_df.columns)
    results_df = results_df.append(row, ignore_index=True)
    conf_mat_plot_heatmap(cm, ['tissue', 'background'], f'{ls[0]} Confusion Matrics')
    
results_df

# %% [markdown]
# # Assess the results of the tissue game

# %%
# determinism preamble
from repath.utils.seeds import set_seed

global_seed = 123
set_seed(global_seed)

# imports
import pandas as pd

# %%
# paths preamble
from repath.utils.paths import project_root
experiment_root = project_root() / "experiments" / "tissue" / "patch_game_analysis"
experiment_root.mkdir(parents=True, exist_ok=True)

# %%
# laod in the results for patches that are marked by everyone
multiple_human_labels = pd.read_csv(experiment_root / "multiple_labeller_patches.csv")
multiple_human_labels
# Out:
#           x      y                                         slide_path  \
# 0    101120  62208         icaird_blood/images/IC-EN-02125-01.isyntax
# 1     79744  90368        icaird_tissue/images/IC-EN-02079-01.isyntax
# 2    130304  42112  icaird_tissue/images_for_game/IC-CX-02343-01.i...
# 3         0   5504        icaird_tissue/images/IC-CX-00004-01.isyntax
# 4       128  21248        icaird_tissue/images/IC-CX-00004-01.isyntax
# ..      ...    ...                                                ...
# 995   14848   2560         icaird_blood/images/IC-EN-02091-01.isyntax
# 996   36096   7040        icaird_tissue/images/IC-EN-02079-01.isyntax
# 997   78080  32384         icaird_blood/images/IC-EN-02175-01.isyntax
# 998   30208  72832        icaird_tissue/images/IC-EN-02079-01.isyntax
# 999  102656  51968         icaird_blood/images/IC-EN-02173-01.isyntax
#
#           label  patch_no           cf           gb           jf           mm  \
# 0    background         0   background   background   background   background
# 1        tissue         1       tissue       tissue       tissue       tissue
# 2        tissue         2       tissue       tissue       tissue       tissue
# 3        tissue         3   background   background   background   background
# 4        tissue         4   background   background   background   background
# ..          ...       ...          ...          ...          ...          ...
# 995  background       995   background   background   background   background
# 996  background       996   background   background   background   background
# 997      tissue       997       tissue       tissue       tissue       tissue
# 998      tissue       998       tissue       tissue       tissue       tissue
# 999      tissue       999       tissue       tissue       tissue       tissue
#
#               pk           sb           tp
# 0     background   background   background
# 1         tissue       tissue       tissue
# 2         tissue       tissue       tissue
# 3     background   background   background
# 4     background   background   background
# ..           ...          ...          ...
# 995   background   background   background
# 996   background   background   background
# 997       tissue       tissue       tissue
# 998       tissue       tissue       tissue
# 999          NaN       tissue       tissue
#
# [1000 rows x 12 columns]

# %%
# load in the results for the patches that are marked by one person
human_patch_labels = pd.read_csv(experiment_root / "human_patch_labels.csv")

# cut out the NaN rows
human_patch_labels = human_patch_labels.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
human_patch_labels
# Out:
#            x      y                                         slide_path  \
# 2000   52096  51072         icaird_blood/images/IC-EN-02132-01.isyntax
# 2001   66816  78080         icaird_blood/images/IC-EN-02175-01.isyntax
# 2002   16640  24576         icaird_blood/images/IC-EN-02091-01.isyntax
# 2003  100608  60800         icaird_blood/images/IC-EN-02091-01.isyntax
# 2004   36352   3200        icaird_tissue/images/IC-EN-02079-01.isyntax
# ...      ...    ...                                                ...
# 9995   67712  23040        icaird_tissue/images/IC-EN-02079-01.isyntax
# 9996   68480  59648         icaird_blood/images/IC-EN-02192-01.isyntax
# 9997   49536  21504        icaird_tissue/images/IC-EN-02092-01.isyntax
# 9998   40960   4992        icaird_tissue/images/IC-EN-02079-01.isyntax
# 9999   13184  40320  icaird_tissue/images_for_game/IC-CX-02323-01.i...
#
#            label  patch_no  human_label
# 2000      tissue      2000       tissue
# 2001  background      2001   background
# 2002      tissue      2002       tissue
# 2003      tissue      2003       tissue
# 2004  background      2004       tissue
# ...          ...       ...          ...
# 9995  background      9995   background
# 9996      tissue      9996       tissue
# 9997  background      9997   background
# 9998  background      9998   background
# 9999  background      9999   background
#
# [7000 rows x 6 columns]

# %%
# do the background subtraction for a slide
from repath.preprocess.tissue_detection import *
from repath.utils.convert import to_frame_with_locations
from repath.data.slides.isyntax import Slide

data_dir = project_root() / 'data'

def as_frame(labels_array, replace_labels=False):
    # change the image into a pandas frame with the labels
    frame = to_frame_with_locations(labels_array, "label")
    if replace_labels:
        frame['label'] = frame['label'].replace( {v: k for k, v in labels.items()})    
    return frame

def label_with_background_subtractor(subtractor, slide_path):
    print(f"labelling: {slide_path}")
    
    # load in the slide
    with Slide(data_dir / slide_path) as slide:
        # pass the level 5 thumbnail into the background subtractor
        thumbnail = slide.get_thumbnail(5)
    labels_array = subtractor(thumbnail)
    df = as_frame(labels_array)
    
    # true == tissue and false == background
    df.loc[df['label'] == True, 'label'] = 'tissue'
    df.loc[df['label'] == False, 'label'] = 'background'
    
    return slide_path, df

def apply_subtractor(subtractor, slide_paths):
    return dict([label_with_background_subtractor(subtractor, s) for s in slide_paths])

# %%
# first let's load in the dataset
# from repath.data.datasets.tissuegame import tissue_game
# tissue_dataset = tissue_game()

# get the paths to each of the unique slides in the human_patch_labels data frame
slide_paths = human_patch_labels['slide_path'].unique().tolist()

# correct for the missing files
corrected_paths = ['icaird_blood/images_valid/IC-EN-02264-01.isyntax', 'icaird_blood/images_test/IC-EN-02262-01.isyntax', 
                   'icaird_blood/images_valid/IC-EN-02152-01.isyntax', 'icaird_blood/images_valid/IC-EN-02254-01.isyntax']
# slide_paths = slide_paths + corrected_paths

# check all the slide paths exist
slide_paths_exist = [sp for sp in slide_paths if (data_dir / sp).exists()]
slide_paths_missing  = [sp for sp in slide_paths if not (data_dir / sp).exists()]
print(f"missing slide paths {slide_paths_missing}")

# set up an array of detectors
subtractors = [TissueDetectorOTSU(), TissueDetectorGreyScale()] 
list_of_path_to_df_dicts = [apply_subtractor(subtractor, slide_paths_exist) for subtractor in subtractors]
# list_of_path_to_df_dicts #  this is a list with a dict for each subtractor
# Out:
# missing slide paths ['icaird_blood/images/IC-EN-02264-01.isyntax', 'icaird_blood/images/IC-EN-02262-01.isyntax', 'icaird_blood/images/IC-EN-02152-01.isyntax', 'icaird_blood/images/IC-EN-02254-01.isyntax']
# labelling: icaird_blood/images/IC-EN-02132-01.isyntax
# labelling: icaird_blood/images/IC-EN-02175-01.isyntax
# labelling: icaird_blood/images/IC-EN-02091-01.isyntax
# labelling: icaird_tissue/images/IC-EN-02079-01.isyntax
# labelling: icaird_blood/images/IC-EN-02104-01.isyntax
# labelling: icaird_blood/images/IC-EN-02263-01.isyntax
# labelling: icaird_tissue/images/IC-EN-02092-01.isyntax
# labelling: icaird_blood/images/IC-EN-02131-01.isyntax
# labelling: icaird_blood/images/IC-EN-02191-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01561-01.isyntax
# labelling: icaird_blood/images/IC-EN-02146-01.isyntax
# labelling: icaird_blood/images/IC-EN-02126-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00005-01.isyntax
# labelling: icaird_blood/images/IC-EN-02121-01.isyntax
# labelling: icaird_blood/images/IC-EN-02117-01.isyntax
# labelling: icaird_blood/images/IC-EN-02219-01.isyntax
# labelling: icaird_blood/images/IC-EN-02110-01.isyntax
# labelling: icaird_tissue/images/IC-EN-02086-01.isyntax
# labelling: icaird_blood/images/IC-EN-02112-01.isyntax
# labelling: icaird_blood/images/IC-EN-02227-01.isyntax
# labelling: icaird_blood/images/IC-EN-02097-01.isyntax
# labelling: icaird_blood/images/IC-EN-02141-01.isyntax
# labelling: icaird_tissue/images/IC-EN-02089-01.isyntax
# labelling: icaird_blood/images/IC-EN-02090-01.isyntax
# labelling: icaird_blood/images/IC-EN-02173-01.isyntax
# labelling: icaird_blood/images/IC-EN-02183-01.isyntax
# labelling: icaird_blood/images/IC-EN-02136-01.isyntax
# labelling: icaird_blood/images/IC-EN-02107-01.isyntax
# labelling: icaird_blood/images/IC-EN-02134-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01677-01.isyntax
# labelling: icaird_blood/images/IC-EN-02128-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00002-01.isyntax
# labelling: icaird_blood/images/IC-EN-02137-01.isyntax
# labelling: icaird_blood/images/IC-EN-02113-01.isyntax
# labelling: icaird_blood/images/IC-EN-02170-01.isyntax
# labelling: icaird_blood/images/IC-EN-02192-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02220-01.isyntax
# labelling: icaird_blood/images/IC-EN-02085-01.isyntax
# labelling: icaird_blood/images/IC-EN-02195-01.isyntax
# labelling: icaird_blood/images/IC-EN-02167-01.isyntax
# labelling: icaird_tissue/images/IC-EN-02081-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00069-01.isyntax
# labelling: icaird_blood/images/IC-EN-02129-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02989-01.isyntax
# labelling: icaird_blood/images/IC-EN-02124-01.isyntax
# labelling: icaird_blood/images/IC-EN-02114-01.isyntax
# labelling: icaird_blood/images/IC-EN-02099-01.isyntax
# labelling: icaird_blood/images/IC-EN-02125-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01274-01.isyntax
# labelling: icaird_blood/images/IC-EN-02130-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00004-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02086-01.isyntax
# labelling: icaird_blood/images/IC-EN-02144-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01553-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00526-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00006-02.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00271-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02748-01.isyntax
# labelling: icaird_blood/images/IC-EN-02106-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01591-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00001-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01105-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02323-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00462-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-03010-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00014-01.isyntax
# labelling: icaird_blood/images/IC-EN-02115-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02219-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01294-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01208-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02353-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02123-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02121-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01778-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01898-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-03070-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01914-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02078-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02838-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01910-01.isyntax
# labelling: icaird_blood/images/IC-EN-02123-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01136-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00550-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02343-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01648-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01485-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01963-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02773-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00773-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01891-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00765-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01613-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00010-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01805-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01780-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00223-01.isyntax
# labelling: icaird_blood/images/IC-EN-02132-01.isyntax
# labelling: icaird_blood/images/IC-EN-02175-01.isyntax
# labelling: icaird_blood/images/IC-EN-02091-01.isyntax
# labelling: icaird_tissue/images/IC-EN-02079-01.isyntax
# labelling: icaird_blood/images/IC-EN-02104-01.isyntax
# labelling: icaird_blood/images/IC-EN-02263-01.isyntax
# labelling: icaird_tissue/images/IC-EN-02092-01.isyntax
# labelling: icaird_blood/images/IC-EN-02131-01.isyntax
# labelling: icaird_blood/images/IC-EN-02191-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01561-01.isyntax
# labelling: icaird_blood/images/IC-EN-02146-01.isyntax
# labelling: icaird_blood/images/IC-EN-02126-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00005-01.isyntax
# labelling: icaird_blood/images/IC-EN-02121-01.isyntax
# labelling: icaird_blood/images/IC-EN-02117-01.isyntax
# labelling: icaird_blood/images/IC-EN-02219-01.isyntax
# labelling: icaird_blood/images/IC-EN-02110-01.isyntax
# labelling: icaird_tissue/images/IC-EN-02086-01.isyntax
# labelling: icaird_blood/images/IC-EN-02112-01.isyntax
# labelling: icaird_blood/images/IC-EN-02227-01.isyntax
# labelling: icaird_blood/images/IC-EN-02097-01.isyntax
# labelling: icaird_blood/images/IC-EN-02141-01.isyntax
# labelling: icaird_tissue/images/IC-EN-02089-01.isyntax
# labelling: icaird_blood/images/IC-EN-02090-01.isyntax
# labelling: icaird_blood/images/IC-EN-02173-01.isyntax
# labelling: icaird_blood/images/IC-EN-02183-01.isyntax
# labelling: icaird_blood/images/IC-EN-02136-01.isyntax
# labelling: icaird_blood/images/IC-EN-02107-01.isyntax
# labelling: icaird_blood/images/IC-EN-02134-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01677-01.isyntax
# labelling: icaird_blood/images/IC-EN-02128-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00002-01.isyntax
# labelling: icaird_blood/images/IC-EN-02137-01.isyntax
# labelling: icaird_blood/images/IC-EN-02113-01.isyntax
# labelling: icaird_blood/images/IC-EN-02170-01.isyntax
# labelling: icaird_blood/images/IC-EN-02192-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02220-01.isyntax
# labelling: icaird_blood/images/IC-EN-02085-01.isyntax
# labelling: icaird_blood/images/IC-EN-02195-01.isyntax
# labelling: icaird_blood/images/IC-EN-02167-01.isyntax
# labelling: icaird_tissue/images/IC-EN-02081-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00069-01.isyntax
# labelling: icaird_blood/images/IC-EN-02129-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02989-01.isyntax
# labelling: icaird_blood/images/IC-EN-02124-01.isyntax
# labelling: icaird_blood/images/IC-EN-02114-01.isyntax
# labelling: icaird_blood/images/IC-EN-02099-01.isyntax
# labelling: icaird_blood/images/IC-EN-02125-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01274-01.isyntax
# labelling: icaird_blood/images/IC-EN-02130-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00004-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02086-01.isyntax
# labelling: icaird_blood/images/IC-EN-02144-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01553-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00526-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00006-02.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00271-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02748-01.isyntax
# labelling: icaird_blood/images/IC-EN-02106-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01591-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00001-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01105-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02323-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00462-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-03010-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00014-01.isyntax
# labelling: icaird_blood/images/IC-EN-02115-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02219-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01294-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01208-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02353-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02123-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02121-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01778-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01898-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-03070-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01914-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02078-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02838-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01910-01.isyntax
# labelling: icaird_blood/images/IC-EN-02123-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01136-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00550-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02343-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01648-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01485-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01963-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-02773-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00773-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01891-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00765-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01613-01.isyntax
# labelling: icaird_tissue/images/IC-CX-00010-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01805-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-01780-01.isyntax
# labelling: icaird_tissue/images_for_game/IC-CX-00223-01.isyntax

# %%
from sklearn.metrics import classification_report

# for each subtractor
for idx, path_to_df_dict in enumerate(list_of_path_to_df_dicts):
    print(f"Subtractor {idx}")
    # iterate over the human marked up patches and compare them to the subtractor output
    targets = []
    predictions = []
    correct = 0
    total = 0
    slide_missing = 0
    for row in human_patch_labels.itertuples():
        x, y, label = row.x // 128, row.y // 128, row.label
        if row.slide_path in path_to_df_dict:
            #print(f"Human prediction for {x}, {y} is {label}")
            predictions_df = path_to_df_dict[row.slide_path]
            # print(predictions_df)
            prediction_row = predictions_df[np.logical_and(predictions_df['column'] == x, predictions_df['row'] == y)]
            #print(prediction_row)
            
            targets.append(label)
            predictions.append(prediction_row['label'])
            total += 1
            if prediction_row['label'].item() == label:
                correct += 1
        else:
            slide_missing += 1
            
    print(f"{len(targets)}, {len(predictions)}")
    print(f"correct: {correct} / {len(targets)} = {correct/len(targets)}")
# Out:
# Subtractor 0
# 6491, 6491
# correct: 3241 / 6491 = 0.4993067323987059
# Subtractor 1
# 6491, 6491
# correct: 3251 / 6491 = 0.5008473270682483
