# %%
import os
import pandas as pd
from pathlib import Path
from os.path import join
from os import walk


project_root = Path('/home/mahnaz/wsi-learning')
root = project_root / "data" / "camelyon17" / "raw" / "training"
annotations_dir = root / "lesion_annotations"

# %%
slide_paths = sorted([os.path.relpath(os.path.join(dirpath, file), root) for (dirpath, dirnames, filenames) in os.walk(root) for file in filenames if ".tif" in file])
slide_paths
# Out:
# ['center_0/patient_015_node_0.tif',
#  'center_0/patient_015_node_1.tif',
#  'center_1/patient_019_node_2.tif']

# %%
annotation_paths = sorted([os.path.relpath(os.path.join(dirpath, file), root) for (dirpath, dirnames, filenames) in os.walk(root) for file in filenames if ".xml" in file])
annotation_paths
# Out:
# ['lesion_annotations/patient_015_node_0.xml']

# %%
slide_names = []
for path in slide_paths:
    head, tail = os.path.split(path)
    slide_names.append(tail.split('.')[0])

slide_names
# Out:
# ['patient_015_node_0', 'patient_015_node_1', 'patient_019_node_2']

# %%
slides_annotations_paths = []
for name in slide_names:
    for anno_path in annotation_paths:
        if  name in anno_path:
            slides_annotations_paths.append(anno_path)
        else:
            slides_annotations_paths.append("")

slides_annotations_paths
# Out:
# ['lesion_annotations/patient_015_node_0.xml', '', '']

# %%
annotation_names = []
for path in annotation_paths:
    head, tail =  os.path.split(path)
    annotation_names.append(tail.split('.')[0])
annotation_names
# Out:
# ['patient_015_node_0']

# %%
labels = pd.read_csv(root / 'stage_labels.csv')
slides_labels_df =labels.loc[labels.stage.isin(["itc", "negative", "micro", "macro"])]
slide_level_labels = slides_labels_df.values.tolist()
slide_level_labels
# Out:
# [['patient_000_node_0.tif', 'negative'],
#  ['patient_000_node_1.tif', 'negative'],
#  ['patient_000_node_2.tif', 'negative'],
#  ['patient_000_node_3.tif', 'negative'],
#  ['patient_000_node_4.tif', 'negative'],
#  ['patient_001_node_0.tif', 'negative'],
#  ['patient_001_node_1.tif', 'negative'],
#  ['patient_001_node_2.tif', 'negative'],
#  ['patient_001_node_3.tif', 'negative'],
#  ['patient_001_node_4.tif', 'negative'],
#  ['patient_002_node_0.tif', 'negative'],
#  ['patient_002_node_1.tif', 'negative'],
#  ['patient_002_node_2.tif', 'negative'],
#  ['patient_002_node_3.tif', 'negative'],
#  ['patient_002_node_4.tif', 'negative'],
#  ['patient_003_node_0.tif', 'negative'],
#  ['patient_003_node_1.tif', 'negative'],
#  ['patient_003_node_2.tif', 'negative'],
#  ['patient_003_node_3.tif', 'negative'],
#  ['patient_003_node_4.tif', 'negative'],
#  ['patient_004_node_0.tif', 'negative'],
#  ['patient_004_node_1.tif', 'negative'],
#  ['patient_004_node_2.tif', 'negative'],
#  ['patient_004_node_3.tif', 'negative'],
#  ['patient_004_node_4.tif', 'itc'],
#  ['patient_005_node_0.tif', 'negative'],
#  ['patient_005_node_1.tif', 'negative'],
#  ['patient_005_node_2.tif', 'negative'],
#  ['patient_005_node_3.tif', 'itc'],
#  ['patient_005_node_4.tif', 'itc'],
#  ['patient_006_node_0.tif', 'negative'],
#  ['patient_006_node_1.tif', 'negative'],
#  ['patient_006_node_2.tif', 'itc'],
#  ['patient_006_node_3.tif', 'negative'],
#  ['patient_006_node_4.tif', 'itc'],
#  ['patient_007_node_0.tif', 'negative'],
#  ['patient_007_node_1.tif', 'negative'],
#  ['patient_007_node_2.tif', 'negative'],
#  ['patient_007_node_3.tif', 'negative'],
#  ['patient_007_node_4.tif', 'micro'],
#  ['patient_008_node_0.tif', 'micro'],
#  ['patient_008_node_1.tif', 'negative'],
#  ['patient_008_node_2.tif', 'negative'],
#  ['patient_008_node_3.tif', 'negative'],
#  ['patient_008_node_4.tif', 'negative'],
#  ['patient_009_node_0.tif', 'itc'],
#  ['patient_009_node_1.tif', 'micro'],
#  ['patient_009_node_2.tif', 'negative'],
#  ['patient_009_node_3.tif', 'negative'],
#  ['patient_009_node_4.tif', 'negative'],
#  ['patient_010_node_0.tif', 'micro'],
#  ['patient_010_node_1.tif', 'negative'],
#  ['patient_010_node_2.tif', 'negative'],
#  ['patient_010_node_3.tif', 'negative'],
#  ['patient_010_node_4.tif', 'micro'],
#  ['patient_011_node_0.tif', 'micro'],
#  ['patient_011_node_1.tif', 'negative'],
#  ['patient_011_node_2.tif', 'negative'],
#  ['patient_011_node_3.tif', 'negative'],
#  ['patient_011_node_4.tif', 'negative'],
#  ['patient_012_node_0.tif', 'macro'],
#  ['patient_012_node_1.tif', 'negative'],
#  ['patient_012_node_2.tif', 'negative'],
#  ['patient_012_node_3.tif', 'negative'],
#  ['patient_012_node_4.tif', 'negative'],
#  ['patient_013_node_0.tif', 'negative'],
#  ['patient_013_node_1.tif', 'negative'],
#  ['patient_013_node_2.tif', 'macro'],
#  ['patient_013_node_3.tif', 'macro'],
#  ['patient_013_node_4.tif', 'micro'],
#  ['patient_014_node_0.tif', 'negative'],
#  ['patient_014_node_1.tif', 'negative'],
#  ['patient_014_node_2.tif', 'macro'],
#  ['patient_014_node_3.tif', 'itc'],
#  ['patient_014_node_4.tif', 'macro'],
#  ['patient_015_node_0.tif', 'negative'],
#  ['patient_015_node_1.tif', 'macro'],
#  ['patient_015_node_2.tif', 'macro'],
#  ['patient_015_node_3.tif', 'negative'],
#  ['patient_015_node_4.tif', 'itc'],
#  ['patient_016_node_0.tif', 'macro'],
#  ['patient_016_node_1.tif', 'itc'],
#  ['patient_016_node_2.tif', 'negative'],
#  ['patient_016_node_3.tif', 'negative'],
#  ['patient_016_node_4.tif', 'negative'],
#  ['patient_017_node_0.tif', 'negative'],
#  ['patient_017_node_1.tif', 'itc'],
#  ['patient_017_node_2.tif', 'macro'],
#  ['patient_017_node_3.tif', 'macro'],
#  ['patient_017_node_4.tif', 'micro'],
#  ['patient_018_node_0.tif', 'negative'],
#  ['patient_018_node_1.tif', 'micro'],
#  ['patient_018_node_2.tif', 'micro'],
#  ['patient_018_node_3.tif', 'macro'],
#  ['patient_018_node_4.tif', 'itc'],
#  ['patient_019_node_0.tif', 'macro'],
#  ['patient_019_node_1.tif', 'macro'],
#  ['patient_019_node_2.tif', 'macro'],
#  ['patient_019_node_3.tif', 'macro'],
#  ['patient_019_node_4.tif', 'negative'],
#  ['patient_020_node_0.tif', 'negative'],
#  ['patient_020_node_1.tif', 'micro'],
#  ['patient_020_node_2.tif', 'micro'],
#  ['patient_020_node_3.tif', 'negative'],
#  ['patient_020_node_4.tif', 'macro'],
#  ['patient_021_node_0.tif', 'macro'],
#  ['patient_021_node_1.tif', 'macro'],
#  ['patient_021_node_2.tif', 'negative'],
#  ['patient_021_node_3.tif', 'micro'],
#  ['patient_021_node_4.tif', 'micro'],
#  ['patient_022_node_0.tif', 'micro'],
#  ['patient_022_node_1.tif', 'micro'],
#  ['patient_022_node_2.tif', 'negative'],
#  ['patient_022_node_3.tif', 'negative'],
#  ['patient_022_node_4.tif', 'macro'],
#  ['patient_023_node_0.tif', 'negative'],
#  ['patient_023_node_1.tif', 'negative'],
#  ['patient_023_node_2.tif', 'negative'],
#  ['patient_023_node_3.tif', 'negative'],
#  ['patient_023_node_4.tif', 'negative'],
#  ['patient_024_node_0.tif', 'negative'],
#  ['patient_024_node_1.tif', 'itc'],
#  ['patient_024_node_2.tif', 'itc'],
#  ['patient_024_node_3.tif', 'negative'],
#  ['patient_024_node_4.tif', 'itc'],
#  ['patient_025_node_0.tif', 'negative'],
#  ['patient_025_node_1.tif', 'negative'],
#  ['patient_025_node_2.tif', 'negative'],
#  ['patient_025_node_3.tif', 'negative'],
#  ['patient_025_node_4.tif', 'negative'],
#  ['patient_026_node_0.tif', 'itc'],
#  ['patient_026_node_1.tif', 'micro'],
#  ['patient_026_node_2.tif', 'macro'],
#  ['patient_026_node_3.tif', 'micro'],
#  ['patient_026_node_4.tif', 'macro'],
#  ['patient_027_node_0.tif', 'micro'],
#  ['patient_027_node_1.tif', 'negative'],
#  ['patient_027_node_2.tif', 'micro'],
#  ['patient_027_node_3.tif', 'negative'],
#  ['patient_027_node_4.tif', 'micro'],
#  ['patient_028_node_0.tif', 'micro'],
#  ['patient_028_node_1.tif', 'micro'],
#  ['patient_028_node_2.tif', 'macro'],
#  ['patient_028_node_3.tif', 'micro'],
#  ['patient_028_node_4.tif', 'negative'],
#  ['patient_029_node_0.tif', 'micro'],
#  ['patient_029_node_1.tif', 'macro'],
#  ['patient_029_node_2.tif', 'itc'],
#  ['patient_029_node_3.tif', 'macro'],
#  ['patient_029_node_4.tif', 'negative'],
#  ['patient_030_node_0.tif', 'negative'],
#  ['patient_030_node_1.tif', 'negative'],
#  ['patient_030_node_2.tif', 'negative'],
#  ['patient_030_node_3.tif', 'negative'],
#  ['patient_030_node_4.tif', 'micro'],
#  ['patient_031_node_0.tif', 'negative'],
#  ['patient_031_node_1.tif', 'negative'],
#  ['patient_031_node_2.tif', 'negative'],
#  ['patient_031_node_3.tif', 'negative'],
#  ['patient_031_node_4.tif', 'negative'],
#  ['patient_032_node_0.tif', 'negative'],
#  ['patient_032_node_1.tif', 'micro'],
#  ['patient_032_node_2.tif', 'negative'],
#  ['patient_032_node_3.tif', 'negative'],
#  ['patient_032_node_4.tif', 'negative'],
#  ['patient_033_node_0.tif', 'negative'],
#  ['patient_033_node_1.tif', 'macro'],
#  ['patient_033_node_2.tif', 'micro'],
#  ['patient_033_node_3.tif', 'micro'],
#  ['patient_033_node_4.tif', 'negative'],
#  ['patient_034_node_0.tif', 'negative'],
#  ['patient_034_node_1.tif', 'negative'],
#  ['patient_034_node_2.tif', 'negative'],
#  ['patient_034_node_3.tif', 'macro'],
#  ['patient_034_node_4.tif', 'negative'],
#  ['patient_035_node_0.tif', 'negative'],
#  ['patient_035_node_1.tif', 'negative'],
#  ['patient_035_node_2.tif', 'negative'],
#  ['patient_035_node_3.tif', 'negative'],
#  ['patient_035_node_4.tif', 'negative'],
#  ['patient_036_node_0.tif', 'negative'],
#  ['patient_036_node_1.tif', 'negative'],
#  ['patient_036_node_2.tif', 'negative'],
#  ['patient_036_node_3.tif', 'micro'],
#  ['patient_036_node_4.tif', 'negative'],
#  ['patient_037_node_0.tif', 'negative'],
#  ['patient_037_node_1.tif', 'itc'],
#  ['patient_037_node_2.tif', 'negative'],
#  ['patient_037_node_3.tif', 'negative'],
#  ['patient_037_node_4.tif', 'negative'],
#  ['patient_038_node_0.tif', 'micro'],
#  ['patient_038_node_1.tif', 'negative'],
#  ['patient_038_node_2.tif', 'micro'],
#  ['patient_038_node_3.tif', 'negative'],
#  ['patient_038_node_4.tif', 'itc'],
#  ['patient_039_node_0.tif', 'macro'],
#  ['patient_039_node_1.tif', 'micro'],
#  ['patient_039_node_2.tif', 'negative'],
#  ['patient_039_node_3.tif', 'negative'],
#  ['patient_039_node_4.tif', 'negative'],
#  ['patient_040_node_0.tif', 'negative'],
#  ['patient_040_node_1.tif', 'negative'],
#  ['patient_040_node_2.tif', 'itc'],
#  ['patient_040_node_3.tif', 'negative'],
#  ['patient_040_node_4.tif', 'negative'],
#  ['patient_041_node_0.tif', 'itc'],
#  ['patient_041_node_1.tif', 'negative'],
#  ['patient_041_node_2.tif', 'negative'],
#  ['patient_041_node_3.tif', 'negative'],
#  ['patient_041_node_4.tif', 'negative'],
#  ['patient_042_node_0.tif', 'negative'],
#  ['patient_042_node_1.tif', 'negative'],
#  ['patient_042_node_2.tif', 'negative'],
#  ['patient_042_node_3.tif', 'macro'],
#  ['patient_042_node_4.tif', 'negative'],
#  ['patient_043_node_0.tif', 'negative'],
#  ['patient_043_node_1.tif', 'negative'],
#  ['patient_043_node_2.tif', 'negative'],
#  ['patient_043_node_3.tif', 'negative'],
#  ['patient_043_node_4.tif', 'negative'],
#  ['patient_044_node_0.tif', 'negative'],
#  ['patient_044_node_1.tif', 'negative'],
#  ['patient_044_node_2.tif', 'negative'],
#  ['patient_044_node_3.tif', 'macro'],
#  ['patient_044_node_4.tif', 'macro'],
#  ['patient_045_node_0.tif', 'macro'],
#  ['patient_045_node_1.tif', 'micro'],
#  ['patient_045_node_2.tif', 'negative'],
#  ['patient_045_node_3.tif', 'macro'],
#  ['patient_045_node_4.tif', 'macro'],
#  ['patient_046_node_0.tif', 'negative'],
#  ['patient_046_node_1.tif', 'negative'],
#  ['patient_046_node_2.tif', 'negative'],
#  ['patient_046_node_3.tif', 'micro'],
#  ['patient_046_node_4.tif', 'micro'],
#  ['patient_047_node_0.tif', 'negative'],
#  ['patient_047_node_1.tif', 'negative'],
#  ['patient_047_node_2.tif', 'macro'],
#  ['patient_047_node_3.tif', 'negative'],
#  ['patient_047_node_4.tif', 'negative'],
#  ['patient_048_node_0.tif', 'micro'],
#  ['patient_048_node_1.tif', 'micro'],
#  ['patient_048_node_2.tif', 'negative'],
#  ['patient_048_node_3.tif', 'negative'],
#  ['patient_048_node_4.tif', 'negative'],
#  ['patient_049_node_0.tif', 'negative'],
#  ['patient_049_node_1.tif', 'micro'],
#  ['patient_049_node_2.tif', 'micro'],
#  ['patient_049_node_3.tif', 'negative'],
#  ['patient_049_node_4.tif', 'negative'],
#  ['patient_050_node_0.tif', 'negative'],
#  ['patient_050_node_1.tif', 'negative'],
#  ['patient_050_node_2.tif', 'negative'],
#  ['patient_050_node_3.tif', 'negative'],
#  ['patient_050_node_4.tif', 'micro'],
#  ['patient_051_node_0.tif', 'macro'],
#  ['patient_051_node_1.tif', 'macro'],
#  ['patient_051_node_2.tif', 'macro'],
#  ['patient_051_node_3.tif', 'negative'],
#  ['patient_051_node_4.tif', 'macro'],
#  ['patient_052_node_0.tif', 'macro'],
#  ['patient_052_node_1.tif', 'macro'],
#  ['patient_052_node_2.tif', 'macro'],
#  ['patient_052_node_3.tif', 'macro'],
#  ['patient_052_node_4.tif', 'negative'],
#  ['patient_053_node_0.tif', 'negative'],
#  ['patient_053_node_1.tif', 'negative'],
#  ['patient_053_node_2.tif', 'negative'],
#  ['patient_053_node_3.tif', 'negative'],
#  ['patient_053_node_4.tif', 'negative'],
#  ['patient_054_node_0.tif', 'negative'],
#  ['patient_054_node_1.tif', 'negative'],
#  ['patient_054_node_2.tif', 'negative'],
#  ['patient_054_node_3.tif', 'negative'],
#  ['patient_054_node_4.tif', 'negative'],
#  ['patient_055_node_0.tif', 'negative'],
#  ['patient_055_node_1.tif', 'negative'],
#  ['patient_055_node_2.tif', 'negative'],
#  ['patient_055_node_3.tif', 'negative'],
#  ['patient_055_node_4.tif', 'negative'],
#  ['patient_056_node_0.tif', 'negative'],
#  ['patient_056_node_1.tif', 'negative'],
#  ['patient_056_node_2.tif', 'negative'],
#  ['patient_056_node_3.tif', 'negative'],
#  ['patient_056_node_4.tif', 'negative'],
#  ['patient_057_node_0.tif', 'negative'],
#  ['patient_057_node_1.tif', 'negative'],
#  ['patient_057_node_2.tif', 'negative'],
#  ['patient_057_node_3.tif', 'negative'],
#  ['patient_057_node_4.tif', 'negative'],
#  ['patient_058_node_0.tif', 'negative'],
#  ['patient_058_node_1.tif', 'negative'],
#  ['patient_058_node_2.tif', 'negative'],
#  ['patient_058_node_3.tif', 'negative'],
#  ['patient_058_node_4.tif', 'negative'],
#  ['patient_059_node_0.tif', 'negative'],
#  ['patient_059_node_1.tif', 'negative'],
#  ['patient_059_node_2.tif', 'negative'],
#  ['patient_059_node_3.tif', 'negative'],
#  ['patient_059_node_4.tif', 'negative'],
#  ['patient_060_node_0.tif', 'micro'],
#  ['patient_060_node_1.tif', 'negative'],
#  ['patient_060_node_2.tif', 'negative'],
#  ['patient_060_node_3.tif', 'itc'],
#  ['patient_060_node_4.tif', 'negative'],
#  ['patient_061_node_0.tif', 'negative'],
#  ['patient_061_node_1.tif', 'negative'],
#  ['patient_061_node_2.tif', 'negative'],
#  ['patient_061_node_3.tif', 'negative'],
#  ['patient_061_node_4.tif', 'micro'],
#  ['patient_062_node_0.tif', 'micro'],
#  ['patient_062_node_1.tif', 'micro'],
#  ['patient_062_node_2.tif', 'macro'],
#  ['patient_062_node_3.tif', 'macro'],
#  ['patient_062_node_4.tif', 'negative'],
#  ['patient_063_node_0.tif', 'macro'],
#  ['patient_063_node_1.tif', 'negative'],
#  ['patient_063_node_2.tif', 'macro'],
#  ['patient_063_node_3.tif', 'macro'],
#  ['patient_063_node_4.tif', 'macro'],
#  ['patient_064_node_0.tif', 'itc'],
#  ['patient_064_node_1.tif', 'negative'],
#  ['patient_064_node_2.tif', 'negative'],
#  ['patient_064_node_3.tif', 'itc'],
#  ['patient_064_node_4.tif', 'negative'],
#  ['patient_065_node_0.tif', 'macro'],
#  ['patient_065_node_1.tif', 'negative'],
#  ['patient_065_node_2.tif', 'negative'],
#  ['patient_065_node_3.tif', 'negative'],
#  ['patient_065_node_4.tif', 'macro'],
#  ['patient_066_node_0.tif', 'negative'],
#  ['patient_066_node_1.tif', 'negative'],
#  ['patient_066_node_2.tif', 'micro'],
#  ['patient_066_node_3.tif', 'macro'],
#  ['patient_066_node_4.tif', 'negative'],
#  ['patient_067_node_0.tif', 'negative'],
#  ['patient_067_node_1.tif', 'negative'],
#  ['patient_067_node_2.tif', 'negative'],
#  ['patient_067_node_3.tif', 'itc'],
#  ['patient_067_node_4.tif', 'micro'],
#  ['patient_068_node_0.tif', 'negative'],
#  ['patient_068_node_1.tif', 'itc'],
#  ['patient_068_node_2.tif', 'negative'],
#  ['patient_068_node_3.tif', 'negative'],
#  ['patient_068_node_4.tif', 'itc'],
#  ['patient_069_node_0.tif', 'macro'],
#  ['patient_069_node_1.tif', 'macro'],
#  ['patient_069_node_2.tif', 'micro'],
#  ['patient_069_node_3.tif', 'micro'],
#  ['patient_069_node_4.tif', 'negative'],
#  ['patient_070_node_0.tif', 'negative'],
#  ['patient_070_node_1.tif', 'negative'],
#  ['patient_070_node_2.tif', 'negative'],
#  ['patient_070_node_3.tif', 'macro'],
#  ['patient_070_node_4.tif', 'negative'],
#  ['patient_071_node_0.tif', 'negative'],
#  ['patient_071_node_1.tif', 'negative'],
#  ['patient_071_node_2.tif', 'negative'],
#  ['patient_071_node_3.tif', 'negative'],
#  ['patient_071_node_4.tif', 'negative'],
#  ['patient_072_node_0.tif', 'itc'],
#  ['patient_072_node_1.tif', 'macro'],
#  ['patient_072_node_2.tif', 'macro'],
#  ['patient_072_node_3.tif', 'negative'],
#  ['patient_072_node_4.tif', 'micro'],
#  ['patient_073_node_0.tif', 'negative'],
#  ['patient_073_node_1.tif', 'macro'],
#  ['patient_073_node_2.tif', 'negative'],
#  ['patient_073_node_3.tif', 'micro'],
#  ['patient_073_node_4.tif', 'negative'],
#  ['patient_074_node_0.tif', 'negative'],
#  ['patient_074_node_1.tif', 'negative'],
#  ['patient_074_node_2.tif', 'negative'],
#  ['patient_074_node_3.tif', 'negative'],
#  ['patient_074_node_4.tif', 'micro'],
#  ['patient_075_node_0.tif', 'negative'],
#  ['patient_075_node_1.tif', 'negative'],
#  ['patient_075_node_2.tif', 'negative'],
#  ['patient_075_node_3.tif', 'negative'],
#  ['patient_075_node_4.tif', 'macro'],
#  ['patient_076_node_0.tif', 'negative'],
#  ['patient_076_node_1.tif', 'macro'],
#  ['patient_076_node_2.tif', 'micro'],
#  ['patient_076_node_3.tif', 'micro'],
#  ['patient_076_node_4.tif', 'itc'],
#  ['patient_077_node_0.tif', 'negative'],
#  ['patient_077_node_1.tif', 'negative'],
#  ['patient_077_node_2.tif', 'macro'],
#  ['patient_077_node_3.tif', 'negative'],
#  ['patient_077_node_4.tif', 'macro'],
#  ['patient_078_node_0.tif', 'negative'],
#  ['patient_078_node_1.tif', 'negative'],
#  ['patient_078_node_2.tif', 'negative'],
#  ['patient_078_node_3.tif', 'negative'],
#  ['patient_078_node_4.tif', 'negative'],
#  ['patient_079_node_0.tif', 'negative'],
#  ['patient_079_node_1.tif', 'negative'],
#  ['patient_079_node_2.tif', 'negative'],
#  ['patient_079_node_3.tif', 'negative'],
#  ['patient_079_node_4.tif', 'negative'],
#  ['patient_080_node_0.tif', 'itc'],
#  ['patient_080_node_1.tif', 'itc'],
#  ['patient_080_node_2.tif', 'macro'],
#  ['patient_080_node_3.tif', 'macro'],
#  ['patient_080_node_4.tif', 'micro'],
#  ['patient_081_node_0.tif', 'negative'],
#  ['patient_081_node_1.tif', 'micro'],
#  ['patient_081_node_2.tif', 'micro'],
#  ['patient_081_node_3.tif', 'negative'],
#  ['patient_081_node_4.tif', 'itc'],
#  ['patient_082_node_0.tif', 'negative'],
#  ['patient_082_node_1.tif', 'negative'],
#  ['patient_082_node_2.tif', 'negative'],
#  ['patient_082_node_3.tif', 'negative'],
#  ['patient_082_node_4.tif', 'negative'],
#  ['patient_083_node_0.tif', 'negative'],
#  ['patient_083_node_1.tif', 'negative'],
#  ['patient_083_node_2.tif', 'negative'],
#  ['patient_083_node_3.tif', 'negative'],
#  ['patient_083_node_4.tif', 'negative'],
#  ['patient_084_node_0.tif', 'negative'],
#  ['patient_084_node_1.tif', 'negative'],
#  ['patient_084_node_2.tif', 'macro'],
#  ['patient_084_node_3.tif', 'macro'],
#  ['patient_084_node_4.tif', 'negative'],
#  ['patient_085_node_0.tif', 'negative'],
#  ['patient_085_node_1.tif', 'negative'],
#  ['patient_085_node_2.tif', 'negative'],
#  ['patient_085_node_3.tif', 'negative'],
#  ['patient_085_node_4.tif', 'negative'],
#  ['patient_086_node_0.tif', 'itc'],
#  ['patient_086_node_1.tif', 'negative'],
#  ['patient_086_node_2.tif', 'negative'],
#  ['patient_086_node_3.tif', 'negative'],
#  ['patient_086_node_4.tif', 'itc'],
#  ['patient_087_node_0.tif', 'itc'],
#  ['patient_087_node_1.tif', 'itc'],
#  ['patient_087_node_2.tif', 'negative'],
#  ['patient_087_node_3.tif', 'negative'],
#  ['patient_087_node_4.tif', 'negative'],
#  ['patient_088_node_0.tif', 'negative'],
#  ['patient_088_node_1.tif', 'micro'],
#  ['patient_088_node_2.tif', 'negative'],
#  ['patient_088_node_3.tif', 'negative'],
#  ['patient_088_node_4.tif', 'itc'],
#  ['patient_089_node_0.tif', 'negative'],
#  ['patient_089_node_1.tif', 'negative'],
#  ['patient_089_node_2.tif', 'negative'],
#  ['patient_089_node_3.tif', 'micro'],
#  ['patient_089_node_4.tif', 'negative'],
#  ['patient_090_node_0.tif', 'negative'],
#  ['patient_090_node_1.tif', 'negative'],
#  ['patient_090_node_2.tif', 'negative'],
#  ['patient_090_node_3.tif', 'negative'],
#  ['patient_090_node_4.tif', 'negative'],
#  ['patient_091_node_0.tif', 'negative'],
#  ['patient_091_node_1.tif', 'negative'],
#  ['patient_091_node_2.tif', 'macro'],
#  ['patient_091_node_3.tif', 'macro'],
#  ['patient_091_node_4.tif', 'macro'],
#  ['patient_092_node_0.tif', 'macro'],
#  ['patient_092_node_1.tif', 'macro'],
#  ['patient_092_node_2.tif', 'negative'],
#  ['patient_092_node_3.tif', 'macro'],
#  ['patient_092_node_4.tif', 'macro'],
#  ['patient_093_node_0.tif', 'negative'],
#  ['patient_093_node_1.tif', 'negative'],
#  ['patient_093_node_2.tif', 'negative'],
#  ['patient_093_node_3.tif', 'negative'],
#  ['patient_093_node_4.tif', 'macro'],
#  ['patient_094_node_0.tif', 'macro'],
#  ['patient_094_node_1.tif', 'macro'],
#  ['patient_094_node_2.tif', 'macro'],
#  ['patient_094_node_3.tif', 'negative'],
#  ['patient_094_node_4.tif', 'macro'],
#  ['patient_095_node_0.tif', 'macro'],
#  ['patient_095_node_1.tif', 'negative'],
#  ['patient_095_node_2.tif', 'negative'],
#  ['patient_095_node_3.tif', 'negative'],
#  ['patient_095_node_4.tif', 'negative'],
#  ['patient_096_node_0.tif', 'macro'],
#  ['patient_096_node_1.tif', 'negative'],
#  ['patient_096_node_2.tif', 'macro'],
#  ['patient_096_node_3.tif', 'macro'],
#  ['patient_096_node_4.tif', 'macro'],
#  ['patient_097_node_0.tif', 'macro'],
#  ['patient_097_node_1.tif', 'macro'],
#  ['patient_097_node_2.tif', 'negative'],
#  ['patient_097_node_3.tif', 'macro'],
#  ['patient_097_node_4.tif', 'macro'],
#  ['patient_098_node_0.tif', 'negative'],
#  ['patient_098_node_1.tif', 'negative'],
#  ['patient_098_node_2.tif', 'negative'],
#  ['patient_098_node_3.tif', 'negative'],
#  ['patient_098_node_4.tif', 'negative'],
#  ['patient_099_node_0.tif', 'negative'],
#  ['patient_099_node_1.tif', 'negative'],
#  ['patient_099_node_2.tif', 'negative'],
#  ['patient_099_node_3.tif', 'negative'],
#  ['patient_099_node_4.tif', 'macro']]

# %%
slide_labels = []
for lst in slide_level_labels:
    if  lst[0].split('.')[0]  in slide_names:
        slide_labels.append(lst[1])
        
slide_labels
# Out:
# ['negative', 'macro', 'macro']

# %%
patient_labels_df = labels.loc[labels.stage.isin(["pN0", "pN1", "pN2", "pN0(i+)", "pN1mi"])]
patient_level_labels = patient_labels_df.values.tolist()
patient_level_labels
# Out:
# [['patient_000.zip', 'pN0'],
#  ['patient_001.zip', 'pN0'],
#  ['patient_002.zip', 'pN0'],
#  ['patient_003.zip', 'pN0'],
#  ['patient_004.zip', 'pN0(i+)'],
#  ['patient_005.zip', 'pN0(i+)'],
#  ['patient_006.zip', 'pN0(i+)'],
#  ['patient_007.zip', 'pN1mi'],
#  ['patient_008.zip', 'pN1mi'],
#  ['patient_009.zip', 'pN1mi'],
#  ['patient_010.zip', 'pN1mi'],
#  ['patient_011.zip', 'pN1mi'],
#  ['patient_012.zip', 'pN1'],
#  ['patient_013.zip', 'pN1'],
#  ['patient_014.zip', 'pN1'],
#  ['patient_015.zip', 'pN1'],
#  ['patient_016.zip', 'pN1'],
#  ['patient_017.zip', 'pN1'],
#  ['patient_018.zip', 'pN1'],
#  ['patient_019.zip', 'pN2'],
#  ['patient_020.zip', 'pN1'],
#  ['patient_021.zip', 'pN2'],
#  ['patient_022.zip', 'pN1'],
#  ['patient_023.zip', 'pN0'],
#  ['patient_024.zip', 'pN0(i+)'],
#  ['patient_025.zip', 'pN0'],
#  ['patient_026.zip', 'pN2'],
#  ['patient_027.zip', 'pN1mi'],
#  ['patient_028.zip', 'pN2'],
#  ['patient_029.zip', 'pN1'],
#  ['patient_030.zip', 'pN1mi'],
#  ['patient_031.zip', 'pN0'],
#  ['patient_032.zip', 'pN1mi'],
#  ['patient_033.zip', 'pN1'],
#  ['patient_034.zip', 'pN1'],
#  ['patient_035.zip', 'pN0'],
#  ['patient_036.zip', 'pN1mi'],
#  ['patient_037.zip', 'pN0(i+)'],
#  ['patient_038.zip', 'pN1mi'],
#  ['patient_039.zip', 'pN1'],
#  ['patient_040.zip', 'pN0(i+)'],
#  ['patient_041.zip', 'pN0(i+)'],
#  ['patient_042.zip', 'pN1'],
#  ['patient_043.zip', 'pN0'],
#  ['patient_044.zip', 'pN1'],
#  ['patient_045.zip', 'pN2'],
#  ['patient_046.zip', 'pN1mi'],
#  ['patient_047.zip', 'pN1'],
#  ['patient_048.zip', 'pN1mi'],
#  ['patient_049.zip', 'pN1mi'],
#  ['patient_050.zip', 'pN1mi'],
#  ['patient_051.zip', 'pN2'],
#  ['patient_052.zip', 'pN2'],
#  ['patient_053.zip', 'pN0'],
#  ['patient_054.zip', 'pN0'],
#  ['patient_055.zip', 'pN0'],
#  ['patient_056.zip', 'pN0'],
#  ['patient_057.zip', 'pN0'],
#  ['patient_058.zip', 'pN0'],
#  ['patient_059.zip', 'pN0'],
#  ['patient_060.zip', 'pN1mi'],
#  ['patient_061.zip', 'pN1mi'],
#  ['patient_062.zip', 'pN2'],
#  ['patient_063.zip', 'pN2'],
#  ['patient_064.zip', 'pN0(i+)'],
#  ['patient_065.zip', 'pN1'],
#  ['patient_066.zip', 'pN1'],
#  ['patient_067.zip', 'pN1mi'],
#  ['patient_068.zip', 'pN0(i+)'],
#  ['patient_069.zip', 'pN2'],
#  ['patient_070.zip', 'pN1'],
#  ['patient_071.zip', 'pN0'],
#  ['patient_072.zip', 'pN1'],
#  ['patient_073.zip', 'pN1'],
#  ['patient_074.zip', 'pN1mi'],
#  ['patient_075.zip', 'pN1'],
#  ['patient_076.zip', 'pN1'],
#  ['patient_077.zip', 'pN1'],
#  ['patient_078.zip', 'pN0'],
#  ['patient_079.zip', 'pN0'],
#  ['patient_080.zip', 'pN1'],
#  ['patient_081.zip', 'pN1mi'],
#  ['patient_082.zip', 'pN0'],
#  ['patient_083.zip', 'pN0'],
#  ['patient_084.zip', 'pN1'],
#  ['patient_085.zip', 'pN0'],
#  ['patient_086.zip', 'pN0(i+)'],
#  ['patient_087.zip', 'pN0(i+)'],
#  ['patient_088.zip', 'pN1mi'],
#  ['patient_089.zip', 'pN1mi'],
#  ['patient_090.zip', 'pN0'],
#  ['patient_091.zip', 'pN1'],
#  ['patient_092.zip', 'pN2'],
#  ['patient_093.zip', 'pN1'],
#  ['patient_094.zip', 'pN2'],
#  ['patient_095.zip', 'pN1'],
#  ['patient_096.zip', 'pN2'],
#  ['patient_097.zip', 'pN2'],
#  ['patient_098.zip', 'pN0'],
#  ['patient_099.zip', 'pN1']]

# %%
patient_names = patient_labels_df.patient.str.split('.')
patient_names = [row[0] for row in patient_names ]

# %%
def intersection(lst1, lst2): 
    return list(set(lst1) & set(lst2)) 
  
slides_names_with_anno = intersection(slide_names, annotation_names)
print(slides_names_with_anno)
slides_names_with_no_anno = [item for item in slide_names if item not in slides_names_with_anno]
print(slides_names_with_no_anno)


tags = []
for sname in slide_names:
    for row in patient_level_labels:
        name = row[0].split('.')[0]
        label = row[1]
        #print(name, label)
        tag = ''
        if sname in slides_names_with_anno and name in sname:
             tag = name + ';' + label + ';' + 'annotated'
        elif sname in slides_names_with_no_anno and name in sname:
             tag = name + ';' + label 
        tags.append(tag)
tags = [tag for tag in tags if tag != ""]
tags
# Out:
# ['patient_015_node_0']
# ['patient_015_node_1', 'patient_019_node_2']
# ['patient_015;pN1;annotated', 'patient_015;pN1', 'patient_019;pN2']

# %%
df = pd.DataFrame()
df["slide"] = slide_paths
df["annotation"] = slides_annotations_paths
df["label"] = slide_labels
df["tags"] = tags
df

# %%
root = project_root / "data" / "camelyon17" / "raw" / "testing"
test_slides_dir = root / "patients"
slide_paths = sorted([p.relative_to(root) for p in test_slides_dir.glob("*.tif")])
slide_paths

# %%
labels = pd.read_csv(root /'evaluation/submission_example.csv')
labels

# %%
slides_labels_df = labels.loc[labels.stage.isin(["itc", "negative", "micro", "macro"])]
slide_level_labels = slides_labels_df.values.tolist()
slide_level_labels

# %%
patient_labels_df = labels.loc[labels.stage.isin(["pN0", "pN1", "pN2", "pN0(i+)", "pN1mi"])]
patient_level_labels = patient_labels_df.values.tolist()
patient_level_labels

# %%
slide_names = []
for path in slide_paths:
    head, tail = os.path.split(path)
    slide_names.append(tail)
slide_names

# %%
#print(slide_level_labels)
slide_labels = []
for lst in slide_level_labels:
    print(lst[0])
    if  lst[0]  in slide_names:
        #print('found')
         slide_labels.append(lst[1])
slide_labels

# %%
tags = []
for lst in patient_level_labels:
    name = lst[0].split('.')[0]
    label = lst[1]
    for spath in slide_paths:
        if name in str(spath):
            tag = name + ';' + label
            tags.append(tag)
        
print(tags)

# %%
df = pd.DataFrame()
df["slide"] = slide_paths
df["annotation"] = ""
df["label"] = slide_labels
df["tags"] =tags
df
