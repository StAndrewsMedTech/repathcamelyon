# %%
import pandas as pd
import numpy as np
import scipy
import csv
from functools import reduce
from scipy import stats

# %%
#Convert excel file and save it as csv file
read_file = pd.read_excel('/home/mahnaz/iCAIRD_DATA_ANALYSIS/iCAIRD Data.xls', sheet_name='iCAIRD_Data')
read_file.to_csv ('/home/mahnaz/iCAIRD_DATA_ANALYSIS/iCAIRD_Data.csv', index= False,  header=True)

# %%
#split Cervical from Endometrial 
df = pd.read_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/iCAIRD_Data.csv')
df['Image Filename'] = df['Image Filename'].map(lambda x: x.lstrip("export\\"))

cervical_df = df[(df['Sample']== 'Cervical')]
cervical_df = cervical_df.sort_values(by=['StudyID'])
cervical_df.index = np.arange(0, len(cervical_df))


endometrial_df = df[(df['Sample']== 'Endometrial')]
endometrial_df = endometrial_df.sort_values(by=['StudyID'])
endometrial_df.index = np.arange(0, len(endometrial_df))

#save the csv files
cervical_df.to_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/iCAIRD_cervical.csv', index = False, header = True)
endometrial_df.to_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/iCAIRD_endometrial.csv', index = False, header = True)


cervical_df
# Out:
#         ID          Image Filename      StudyID    Sample  \
# 0     4719  IC-CX-00001-01.isyntax  IC-CX-00001  Cervical
# 1     2396  IC-CX-00002-01.isyntax  IC-CX-00002  Cervical
# 2     2586  IC-CX-00002-02.isyntax  IC-CX-00002  Cervical
# 3     2358  IC-CX-00003-01.isyntax  IC-CX-00003  Cervical
# 4     2596  IC-CX-00004-01.isyntax  IC-CX-00004  Cervical
# ...    ...                     ...          ...       ...
# 2598  4045  IC-CX-03136-01.isyntax  IC-CX-03136  Cervical
# 2599  2793  IC-CX-03137-01.isyntax  IC-CX-03137  Cervical
# 2600  4024  IC-CX-03138-01.isyntax  IC-CX-03138  Cervical
# 2601  2541  IC-CX-03139-01.isyntax  IC-CX-03139  Cervical
# 2602    79  IC-CX-03140-01.isyntax  IC-CX-03140  Cervical
#
#                  Category          subCategory
# 0     Normal/inflammation  Normal/inflammation
# 1               Malignant                Other
# 2               Malignant                Other
# 3              High Grade                CIN 2
# 4     Normal/inflammation  Normal/inflammation
# ...                   ...                  ...
# 2598            Low Grade                  HPV
# 2599           High Grade                CIN 3
# 2600            Malignant       Adenocarcinoma
# 2601           High Grade                CIN 3
# 2602  Normal/inflammation  Normal/inflammation
#
# [2603 rows x 6 columns]

# %%
#Convert txt file to csv
with open('/home/mahnaz/iCAIRD_DATA_ANALYSIS/iCAIRD_Samples_Details.txt', 'r', encoding='unicode_escape') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line.split(",") for line in stripped if line)
    with open('/home/mahnaz/iCAIRD_DATA_ANALYSIS/iCAIRD_Samples_Details.csv', 'w') as out_file:
        writer = csv.writer(out_file)
        writer.writerows(lines)

# %%
# read iCAIRD sample details file 
df = pd.read_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/iCAIRD_Samples_Details.csv')

df1 = df[(df['SampleType']== '"CX"')]
df2 = df[(df['SampleType']== '"EN"')]

cervical_staining_info = df1[['StudyID','StainingSiteID','StainingProtocol']]
endometrial_staining_info = df2[['StudyID','StainingSiteID','StainingProtocol']]


cervical_staining_info.to_csv('cervical_staining_info.csv',index = False, header = True)
endometrial_staining_info.to_csv('endometrial_staining_info.csv', index = False, header = True)

cervical_staining_info
# Out:
#              StudyID  StainingSiteID                   StainingProtocol
# 0     "IC-CX-00001 "               3                   "paeds protocol"
# 1     "IC-CX-00002 "               2                      "routine H&E"
# 2     "IC-CX-00003 "               7  "muscle (hand staining protocol)"
# 3     "IC-CX-00004 "               1                      "routine H&E"
# 4     "IC-CX-00005 "               3                   "paeds protocol"
# ...              ...             ...                                ...
# 2704  "IC-CX-03136 "               2                      "routine H&E"
# 2705  "IC-CX-03137 "               3                   "paeds protocol"
# 2706  "IC-CX-03138 "               2                      "routine H&E"
# 2707  "IC-CX-03139 "               4                   "paeds protocol"
# 2708  "IC-CX-03140 "               6   "neuro (hand staining protocol)"
#
# [2709 rows x 3 columns]

# %%
#read staining info csv files
cervical_staining_info = pd.read_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/cervical_staining_info.csv', sep = ',').replace('"','', regex=True)
endometrial_staining_info = pd.read_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/endometrial_staining_info.csv', sep = ',').replace('"','', regex=True)

#save the files after removing the qutations around values
cervical_staining_info.to_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/cervical_staining.csv', index = False)
endometrial_staining_info .to_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/endometrial_staining.csv', index = False)

#read the csv files to Dataframes
cervical_staining = pd.read_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/cervical_staining.csv')
endometrial_staining = pd.read_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/endometrial_staining.csv')

cervical_staining
# Out:
#            StudyID  StainingSiteID                 StainingProtocol
# 0     IC-CX-00001                3                   paeds protocol
# 1     IC-CX-00002                2                      routine H&E
# 2     IC-CX-00003                7  muscle (hand staining protocol)
# 3     IC-CX-00004                1                      routine H&E
# 4     IC-CX-00005                3                   paeds protocol
# ...            ...             ...                              ...
# 2704  IC-CX-03136                2                      routine H&E
# 2705  IC-CX-03137                3                   paeds protocol
# 2706  IC-CX-03138                2                      routine H&E
# 2707  IC-CX-03139                4                   paeds protocol
# 2708  IC-CX-03140                6   neuro (hand staining protocol)
#
# [2709 rows x 3 columns]

# %%
#join two dataframes for Cervical
result1 = pd.concat([cervical_df, cervical_staining], axis=1, join="inner")
result1.columns.values[6]= 'BiobankID'

# All samples from staining Site 6 and 8 are test samples
result1.loc[result1.StainingSiteID == 6, 'train/valid/test'] = 'test'
result1.loc[result1.StainingSiteID == 8, 'train/valid/test'] = 'test'



#join two dataframes for Endometrial
result2 = pd.concat([endometrial_df, endometrial_staining], axis=1, join="inner")
result2.columns.values[6]= 'BiobankID'

# All samples from staining Site 6 and 8 are test samples
result2.loc[result2.StainingSiteID == 6, 'train/valid/test'] = 'test'
result2.loc[result2.StainingSiteID == 8, 'train/valid/test'] = 'test'


result1
# Out:
#         ID          Image Filename      StudyID    Sample  \
# 0     4719  IC-CX-00001-01.isyntax  IC-CX-00001  Cervical
# 1     2396  IC-CX-00002-01.isyntax  IC-CX-00002  Cervical
# 2     2586  IC-CX-00002-02.isyntax  IC-CX-00002  Cervical
# 3     2358  IC-CX-00003-01.isyntax  IC-CX-00003  Cervical
# 4     2596  IC-CX-00004-01.isyntax  IC-CX-00004  Cervical
# ...    ...                     ...          ...       ...
# 2598  4045  IC-CX-03136-01.isyntax  IC-CX-03136  Cervical
# 2599  2793  IC-CX-03137-01.isyntax  IC-CX-03137  Cervical
# 2600  4024  IC-CX-03138-01.isyntax  IC-CX-03138  Cervical
# 2601  2541  IC-CX-03139-01.isyntax  IC-CX-03139  Cervical
# 2602    79  IC-CX-03140-01.isyntax  IC-CX-03140  Cervical
#
#                  Category          subCategory     BiobankID  StainingSiteID  \
# 0     Normal/inflammation  Normal/inflammation  IC-CX-00001                3
# 1               Malignant                Other  IC-CX-00002                2
# 2               Malignant                Other  IC-CX-00003                7
# 3              High Grade                CIN 2  IC-CX-00004                1
# 4     Normal/inflammation  Normal/inflammation  IC-CX-00005                3
# ...                   ...                  ...           ...             ...
# 2598            Low Grade                  HPV  IC-CX-03019                8
# 2599           High Grade                CIN 3  IC-CX-03020                1
# 2600            Malignant       Adenocarcinoma  IC-CX-03021                1
# 2601           High Grade                CIN 3  IC-CX-03022                1
# 2602  Normal/inflammation  Normal/inflammation  IC-CX-03023                8
#
#                      StainingProtocol train/valid/test
# 0                      paeds protocol              NaN
# 1                         routine H&E              NaN
# 2     muscle (hand staining protocol)              NaN
# 3                         routine H&E              NaN
# 4                      paeds protocol              NaN
# ...                               ...              ...
# 2598  muscle (hand staining protocol)             test
# 2599                      routine H&E              NaN
# 2600                      routine H&E              NaN
# 2601                      routine H&E              NaN
# 2602  muscle (hand staining protocol)             test
#
# [2603 rows x 10 columns]

# %%
#number of test samples from stain labs 6 and 8 for cervical and endometrial
test_cervical = len(result1[result1['train/valid/test'] == 'test'])
test_endo =  len(result2[result2['train/valid/test'] == 'test'])

print('Number of test samples form stain labs 6 & 8 is {} in Cervical data'.format(test_cervical))
print('Number of test samples form stain labs 6 & 8 is {} in Endometrial data'.format(test_endo))
# Out:
# Number of test samples form stain labs 6 & 8 is 650 in Cervical data
# Number of test samples form stain labs 6 & 8 is 738 in Endometrial data

# %%
# Add 10% of samples from other staining sites to test (Balanced based of categories and stain labs)
#for Cervical
remain1 = result1[result1['train/valid/test'].isna()]
grouped1 = remain1.groupby(['Category', 'StainingSiteID']).apply(lambda x: x.sample(frac = 0.1))

grouped1
# Out:
#                                            ID          Image Filename  \
# Category            StainingSiteID
# High Grade          1              1505  2780  IC-CX-01822-01.isyntax
#                                    508   2894  IC-CX-00630-01.isyntax
#                                    65    4510  IC-CX-00081-01.isyntax
#                                    2416  2494  IC-CX-02927-01.isyntax
#                                    1365  1798  IC-CX-01655-01.isyntax
# ...                                       ...                     ...
# Normal/inflammation 7              751    281  IC-CX-00928-01.isyntax
#                                    2123  4523  IC-CX-02573-01.isyntax
#                                    949    467  IC-CX-01164-01.isyntax
#                                    1307  5191  IC-CX-01587-01.isyntax
#                                    309   4566  IC-CX-00380-01.isyntax
#
#                                              StudyID    Sample  \
# Category            StainingSiteID
# High Grade          1              1505  IC-CX-01822  Cervical
#                                    508   IC-CX-00630  Cervical
#                                    65    IC-CX-00081  Cervical
#                                    2416  IC-CX-02927  Cervical
#                                    1365  IC-CX-01655  Cervical
# ...                                              ...       ...
# Normal/inflammation 7              751   IC-CX-00928  Cervical
#                                    2123  IC-CX-02573  Cervical
#                                    949   IC-CX-01164  Cervical
#                                    1307  IC-CX-01587  Cervical
#                                    309   IC-CX-00380  Cervical
#
#                                                     Category  \
# Category            StainingSiteID
# High Grade          1              1505           High Grade
#                                    508            High Grade
#                                    65             High Grade
#                                    2416           High Grade
#                                    1365           High Grade
# ...                                                      ...
# Normal/inflammation 7              751   Normal/inflammation
#                                    2123  Normal/inflammation
#                                    949   Normal/inflammation
#                                    1307  Normal/inflammation
#                                    309   Normal/inflammation
#
#                                                  subCategory     BiobankID  \
# Category            StainingSiteID
# High Grade          1              1505                CIN 3  IC-CX-01753
#                                    508                 CIN 2  IC-CX-00606
#                                    65                  CIN 2  IC-CX-00078
#                                    2416                CIN 3  IC-CX-02818
#                                    1365                CIN 2  IC-CX-01591
# ...                                                      ...           ...
# Normal/inflammation 7              751   Normal/inflammation  IC-CX-00892
#                                    2123  Normal/inflammation  IC-CX-02467
#                                    949   Normal/inflammation  IC-CX-01123
#                                    1307  Normal/inflammation  IC-CX-01528
#                                    309   Normal/inflammation  IC-CX-00360
#
#                                          StainingSiteID  \
# Category            StainingSiteID
# High Grade          1              1505               1
#                                    508                1
#                                    65                 1
#                                    2416               1
#                                    1365               1
# ...                                                 ...
# Normal/inflammation 7              751                7
#                                    2123               7
#                                    949                7
#                                    1307               7
#                                    309                7
#
#                                                         StainingProtocol  \
# Category            StainingSiteID
# High Grade          1              1505                      routine H&E
#                                    508                       routine H&E
#                                    65                        routine H&E
#                                    2416                      routine H&E
#                                    1365                      routine H&E
# ...                                                                  ...
# Normal/inflammation 7              751   muscle (hand staining protocol)
#                                    2123  muscle (hand staining protocol)
#                                    949   muscle (hand staining protocol)
#                                    1307  muscle (hand staining protocol)
#                                    309   muscle (hand staining protocol)
#
#                                         train/valid/test
# Category            StainingSiteID
# High Grade          1              1505              NaN
#                                    508               NaN
#                                    65                NaN
#                                    2416              NaN
#                                    1365              NaN
# ...                                                  ...
# Normal/inflammation 7              751               NaN
#                                    2123              NaN
#                                    949               NaN
#                                    1307              NaN
#                                    309               NaN
#
# [195 rows x 10 columns]

# %%
file_names = grouped1['Image Filename'].tolist()
for name in file_names :
    result1.loc[(result1['Image Filename'] == name),'train/valid/test']='test'

result1.loc[(result1['train/valid/test'].isna()), 'train/valid/test'] = 'train'
result1
# Out:
#         ID          Image Filename      StudyID    Sample  \
# 0     4719  IC-CX-00001-01.isyntax  IC-CX-00001  Cervical
# 1     2396  IC-CX-00002-01.isyntax  IC-CX-00002  Cervical
# 2     2586  IC-CX-00002-02.isyntax  IC-CX-00002  Cervical
# 3     2358  IC-CX-00003-01.isyntax  IC-CX-00003  Cervical
# 4     2596  IC-CX-00004-01.isyntax  IC-CX-00004  Cervical
# ...    ...                     ...          ...       ...
# 2598  4045  IC-CX-03136-01.isyntax  IC-CX-03136  Cervical
# 2599  2793  IC-CX-03137-01.isyntax  IC-CX-03137  Cervical
# 2600  4024  IC-CX-03138-01.isyntax  IC-CX-03138  Cervical
# 2601  2541  IC-CX-03139-01.isyntax  IC-CX-03139  Cervical
# 2602    79  IC-CX-03140-01.isyntax  IC-CX-03140  Cervical
#
#                  Category          subCategory     BiobankID  StainingSiteID  \
# 0     Normal/inflammation  Normal/inflammation  IC-CX-00001                3
# 1               Malignant                Other  IC-CX-00002                2
# 2               Malignant                Other  IC-CX-00003                7
# 3              High Grade                CIN 2  IC-CX-00004                1
# 4     Normal/inflammation  Normal/inflammation  IC-CX-00005                3
# ...                   ...                  ...           ...             ...
# 2598            Low Grade                  HPV  IC-CX-03019                8
# 2599           High Grade                CIN 3  IC-CX-03020                1
# 2600            Malignant       Adenocarcinoma  IC-CX-03021                1
# 2601           High Grade                CIN 3  IC-CX-03022                1
# 2602  Normal/inflammation  Normal/inflammation  IC-CX-03023                8
#
#                      StainingProtocol train/valid/test
# 0                      paeds protocol            train
# 1                         routine H&E            train
# 2     muscle (hand staining protocol)            train
# 3                         routine H&E            train
# 4                      paeds protocol            train
# ...                               ...              ...
# 2598  muscle (hand staining protocol)             test
# 2599                      routine H&E            train
# 2600                      routine H&E            train
# 2601                      routine H&E            train
# 2602  muscle (hand staining protocol)             test
#
# [2603 rows x 10 columns]

# %%
# Add 10% of samples from other staining sites to test (Balanced based of categories and stain labs)
#for Endometrial
remain2 = result2[result2['train/valid/test'].isna()]
grouped2 = remain2.groupby(['Category', 'StainingSiteID']).apply(lambda x: x.sample(frac = 0.1))
grouped2
# Out:
#                                     ID          Image Filename      StudyID  \
# Category     StainingSiteID
# Insufficient 1              2428  3370  IC-EN-02660-01.isyntax  IC-EN-02660
#                             1182  3828  IC-EN-01301-01.isyntax  IC-EN-01301
#              2              2311  2062  IC-EN-02535-01.isyntax  IC-EN-02535
#                             256   1306  IC-EN-00285-01.isyntax  IC-EN-00285
#              3              749   1272  IC-EN-00821-01.isyntax  IC-EN-00821
# ...                                ...                     ...          ...
# Other/benign 7              1922  3065  IC-EN-02108-01.isyntax  IC-EN-02108
#                             989   2651  IC-EN-01079-01.isyntax  IC-EN-01079
#                             2869  4935  IC-EN-03140-01.isyntax  IC-EN-03140
#                             1119  2861  IC-EN-01231-01.isyntax  IC-EN-01231
#                             208   3056  IC-EN-00233-01.isyntax  IC-EN-00233
#
#                                        Sample      Category  \
# Category     StainingSiteID
# Insufficient 1              2428  Endometrial  Insufficient
#                             1182  Endometrial  Insufficient
#              2              2311  Endometrial  Insufficient
#                             256   Endometrial  Insufficient
#              3              749   Endometrial  Insufficient
# ...                                       ...           ...
# Other/benign 7              1922  Endometrial  Other/benign
#                             989   Endometrial  Other/benign
#                             2869  Endometrial  Other/benign
#                             1119  Endometrial  Other/benign
#                             208   Endometrial  Other/benign
#
#                                          subCategory     BiobankID  \
# Category     StainingSiteID
# Insufficient 1              2428        Insufficient  IC-EN-02526
#                             1182        Insufficient  IC-EN-01232
#              2              2311        Insufficient  IC-EN-02402
#                             256         Insufficient  IC-EN-00268
#              3              749         Insufficient  IC-EN-00775
# ...                                              ...           ...
# Other/benign 7              1922  Innactive/atrophic  IC-EN-01999
#                             989   Innactive/atrophic  IC-EN-01024
#                             2869  Innactive/atrophic  IC-EN-02982
#                             1119  Innactive/atrophic  IC-EN-01164
#                             208             Hormonal  IC-EN-00218
#
#                                   StainingSiteID  \
# Category     StainingSiteID
# Insufficient 1              2428               1
#                             1182               1
#              2              2311               2
#                             256                2
#              3              749                3
# ...                                          ...
# Other/benign 7              1922               7
#                             989                7
#                             2869               7
#                             1119               7
#                             208                7
#
#                                                  StainingProtocol  \
# Category     StainingSiteID
# Insufficient 1              2428                      routine H&E
#                             1182                      routine H&E
#              2              2311                      routine H&E
#                             256                       routine H&E
#              3              749                    paeds protocol
# ...                                                           ...
# Other/benign 7              1922  muscle (hand staining protocol)
#                             989   muscle (hand staining protocol)
#                             2869  muscle (hand staining protocol)
#                             1119  muscle (hand staining protocol)
#                             208   muscle (hand staining protocol)
#
#                                  train/valid/test
# Category     StainingSiteID
# Insufficient 1              2428              NaN
#                             1182              NaN
#              2              2311              NaN
#                             256               NaN
#              3              749               NaN
# ...                                           ...
# Other/benign 7              1922              NaN
#                             989               NaN
#                             2869              NaN
#                             1119              NaN
#                             208               NaN
#
# [221 rows x 10 columns]

# %%
file_names = grouped2['Image Filename'].tolist()
for name in file_names :
    result2.loc[(result2['Image Filename'] == name),'train/valid/test']='test'

result2.loc[(result2['train/valid/test'].isna()), 'train/valid/test'] = 'train'
result2
# Out:
#         ID          Image Filename      StudyID       Sample      Category  \
# 0     2520  IC-EN-00001-01.isyntax  IC-EN-00001  Endometrial  Other/benign
# 1     3814  IC-EN-00003-01.isyntax  IC-EN-00003  Endometrial  Other/benign
# 2     2653  IC-EN-00004-01.isyntax  IC-EN-00004  Endometrial  Other/benign
# 3     1164  IC-EN-00005-01.isyntax  IC-EN-00005  Endometrial  Other/benign
# 4     4193  IC-EN-00006-01.isyntax  IC-EN-00006  Endometrial  Other/benign
# ...    ...                     ...          ...          ...           ...
# 2943  1657  IC-EN-03221-01.isyntax  IC-EN-03221  Endometrial     Malignant
# 2944  3252  IC-EN-03222-01.isyntax  IC-EN-03222  Endometrial  Other/benign
# 2945  5258  IC-EN-03223-01.isyntax  IC-EN-03223  Endometrial  Other/benign
# 2946  2466  IC-EN-03224-01.isyntax  IC-EN-03224  Endometrial  Other/benign
# 2947  2587  IC-EN-12346-01.isyntax  IC-EN-12346  Endometrial           NaN
#
#              subCategory     BiobankID  StainingSiteID  \
# 0              Menstrual  IC-EN-00001                3
# 1              Secretory  IC-EN-00003                3
# 2              Secretory  IC-EN-00004                1
# 3              Menstrual  IC-EN-00005                8
# 4     Innactive/atrophic  IC-EN-00006                1
# ...                  ...           ...             ...
# 2943      Adenocarcinoma  IC-EN-03061                1
# 2944           Menstrual  IC-EN-03062                6
# 2945           Menstrual  IC-EN-03063                2
# 2946           Secretory  IC-EN-03064                2
# 2947                 NaN  IC-EN-03065                6
#
#                      StainingProtocol train/valid/test
# 0                      paeds protocol            train
# 1                      paeds protocol             test
# 2                         routine H&E            train
# 3     muscle (hand staining protocol)             test
# 4                         routine H&E            train
# ...                               ...              ...
# 2943                      routine H&E            train
# 2944   neuro (hand staining protocol)             test
# 2945                      routine H&E            train
# 2946                      routine H&E             test
# 2947   neuro (hand staining protocol)             test
#
# [2948 rows x 10 columns]

# %%
train_cervical = len(result1[result1['train/valid/test'] == 'train'])
test_cervical =  len(result1[result1['train/valid/test'] == 'test'])
print('Number of train samples is {} and test samples is {} in Cervical data'.format(train_cervical, test_cervical))

train_endo = len(result2[result2['train/valid/test'] == 'train'])
test_endo =  len(result2[result2['train/valid/test'] == 'test'])
print('Number of train samples is {} and test samples is {} in Endometrial data'.format(train_endo, test_endo))
# Out:
# Number of train samples is 1758 and test samples is 845 in Cervical data
# Number of train samples is 1989 and test samples is 959 in Endometrial data

# %%
#save final dataframes as csv files
result1.to_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/iCAIRD_Cervical_Data.csv', index= False, header = True)
result2.to_csv('/home/mahnaz/iCAIRD_DATA_ANALYSIS/iCAIRD_Endometrial_Data.csv', index= False, header = True)
