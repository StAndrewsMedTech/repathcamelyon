# %% [markdown]
# # Wang

# %% [markdown]
# ## Patch level results

# %%
exp_pathw = "/home/ubuntu/repath/experiments/wang/"

# %% [markdown]
# ### Pre hard negative mining

# %%
wpre = "pre_hnm_results/patch_summaries/"

# %% [markdown]
# #### Validation set

# %%
from PIL import Image

wvalidpr = exp_pathw + wpre + "valid16/" 

wprev_cm = wvalidpr + "confidence_matrix.png"

Image.open(wprev_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F53200B2BA8>

# %%
wprev_cur = wvalidpr + "patch_pr_curve.png"
Image.open(wprev_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AA09E8>

# %% [markdown]
# #### Test set

# %%
wtestpr = exp_pathw + wpre + "test16/" 

wpret_cm = wtestpr + "confidence_matrix.png"

Image.open(wpret_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312AA0E10>

# %%
wpret_cur = wtestpr + "patch_pr_curve.png"
Image.open(wpret_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AA0C18>

# %% [markdown]
# ### Post hard negative mining

# %%
wpost = "post_hnm_results/patch_summaries/"

# %% [markdown]
# #### Validation set

# %%
wvalidpo = exp_pathw + wpost + "valid16/" 

wpostv_cm = wvalidpo + "confidence_matrix.png"

Image.open(wpostv_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312AC2550>

# %%
wpostv_cur = wvalidpo + "patch_pr_curve.png"
Image.open(wpostv_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AC2828>

# %% [markdown]
# #### Test set

# %%
wtestpo = exp_pathw + wpost + "test16/" 

wpostt_cm = wtestpo + "confidence_matrix.png"

Image.open(wpostt_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312AC2780>

# %%
wpostt_cur = wtestpo + "patch_pr_curve.png"
Image.open(wpostt_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AC2588>

# %% [markdown]
# ## Slide level results

# %% [markdown]
# ### Pre hard negative mining

# %% [markdown]
# #### Validation Set

# %%
wpreval16 = exp_pathw + "pre_hnm_results/slide_results16_valid/" 

wprevalsl16_cm = wpreval16 + "confidence_matrix.png"

Image.open(wprevalsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312AC2AC8>

# %%
wprevalsl16_cur = wpreval16 + "slide_pr_curve.png"

Image.open(wprevalsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AC2C50>

# %% [markdown]
# #### Test Set

# %%
wpretest16 = exp_pathw + "pre_hnm_results/slide_results16_test/" 

wpretestsl16_cm = wpretest16 + "confidence_matrix.png"

Image.open(wpretestsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312ACE160>

# %%
wpretestsl16_cur = wpretest16 + "slide_pr_curve.png"

Image.open(wpretestsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312ACE358>

# %% [markdown]
# ### Post hard negative mining

# %% [markdown]
# #### Validation Set

# %%
wposval16 = exp_pathw + "post_hnm_results/slide_results16_valid/" 

wposvalsl16_cm = wposval16 + "confidence_matrix.png"

Image.open(wposvalsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312ACE828>

# %%
wposvalsl16_cur = wposval16 + "slide_pr_curve.png"

Image.open(wposvalsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312ACEAC8>

# %% [markdown]
# #### Test Set

# %%
wpostest16 = exp_pathw + "post_hnm_results/slide_results16_test/" 

wtestsl16_cm = wpostest16 + "confidence_matrix.png"

Image.open(wtestsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312ACEF28>

# %%
wtestsl16_cur = wpostest16 + "slide_pr_curve.png"

Image.open(wtestsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AD3198>

# %% [markdown]
# ## Lesion Level results

# %% [markdown]
# ### Validation set

# %%
wposval16les = exp_pathw + "post_hnm_results/lesion_results/valid16/froc_curve.png" 
Image.open(wposval16les)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AD3588>

# %% [markdown]
# ### Test Set

# %%
wpostst16les = exp_pathw + "post_hnm_results/lesion_results/test16/froc_curve.png" 
Image.open(wpostst16les)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AD3898>

# %% [markdown]
# # Lee

# %% [markdown]
# ## Patch level results

# %%
exp_pathle = "/home/ubuntu/repath/experiments/lee/"

lepost = "post_hnm_results/patch_summaries/"

# %% [markdown]
# ### Validation set

# %% [markdown]
# #### Camelyon 16

# %%
levalidpo16 = exp_pathle + lepost + "valid16/" 

lepostv16_cm = levalidpo16 + "confidence_matrix.png"

Image.open(lepostv16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312AD90F0>

# %%
lepostv16_cur = levalidpo16 + "patch_pr_curve.png"
Image.open(lepostv16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AD9358>

# %% [markdown]
# #### Camelyon 17

# %%
levalidpo17 = exp_pathle + lepost + "valid17/" 

lepostv17_cm = levalidpo17 + "confidence_matrix.png"

Image.open(lepostv17_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F53200C4A20>

# %%
lepostv17_cur = levalidpo17 + "patch_pr_curve.png"
Image.open(lepostv17_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AA0E80>

# %% [markdown]
# #### Combined camelyon 16 and 17

# %%
levalidpo1617 = exp_pathle + lepost + "valid1617/" 

lepostv1617_cm = levalidpo1617 + "confidence_matrix.png"

Image.open(lepostv1617_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312AD3CF8>

# %%
lepostv1617_cur = levalidpo1617 + "patch_pr_curve.png"
Image.open(lepostv1617_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AD3860>

# %% [markdown]
# ### Test set

# %% [markdown]
# #### Camelyon 16

# %%
letestpo16 = exp_pathle + lepost + "test16/" 

lepret16_cm = letestpo16 + "confidence_matrix.png"

Image.open(lepret16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312AD3160>

# %%
lepostt16_cur = letestpo16 + "patch_pr_curve.png"
Image.open(lepostt16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AD3630>

# %% [markdown]
# #### camelyon 17 - no annotations for test images for camelyon 17 so no patch level comparisons

# %% [markdown]
# #### Combined camelyon 16 and 17 - no annotations for test images for camelyon 17 so no combined patch level comparisons

# %% [markdown]
# ## Slide level results

# %% [markdown]
# ### Validation set

# %% [markdown]
# #### camelyon 16

# %%
levalsl16 = exp_pathle + "post_hnm_results/slide_results16_valid/"

levalsl16_cm = levalsl16 + "confidence_matrix.png"

Image.open(levalsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312AD92E8>

# %%
levalsl16_cur = levalsl16 + "slide_pr_curve.png"

Image.open(levalsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AD92B0>

# %% [markdown]
# #### camelyon 17

# %%
levalsl17 = exp_pathle + "post_hnm_results/slide_results17_valid/"

levalsl17_cm = levalsl17 + "confidence_matrix.png"

Image.open(levalsl17_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312AD95F8>

# %% [markdown]
# No PR curve as multi class

# %% [markdown]
# ### Test Set

# %% [markdown]
# #### Camelyon 16

# %%
letestsl16 = exp_pathle + "post_hnm_results/slide_results16_test/"

letestsl16_cm = letestsl16 + "confidence_matrix.png"

Image.open(letestsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312AD9DD8>

# %%
letestsl16_cur = letestsl16 + "slide_pr_curve.png"

Image.open(letestsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312AD9E48>

# %% [markdown]
# #### Camelyon 17

# %%
letestsl17 = exp_pathle + "post_hnm_results/slide_results17_test/"

letestsl17_cm = letestsl17 + "confidence_matrix.png"

Image.open(letestsl17_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312A6F0B8>

# %% [markdown]
# No PR curve as multi class

# %% [markdown]
# ## Patient level results

# %% [markdown]
# ### Validation set

# %%
levalpat17 = exp_pathle + "post_hnm_results/patient_results17_valid/"

levalpat17_cm = levalpat17 + "confidence_matrix.png"

Image.open(levalpat17_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312A6F208>

# %% [markdown]
# ### Test set

# %%
letstpat17 = exp_pathle + "post_hnm_results/patient_results17_test/"

letstpat17_cm = letstpat17 + "confidence_matrix.png"

Image.open(letstpat17_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312A6F3C8>

# %% [markdown]
# ## Lesion level results

# %% [markdown]
# ### Validation set

# %%
leposval16les = exp_pathle + "post_hnm_results/lesion_results/valid16/froc_curve.png" 
Image.open(leposval16les)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312A6F438>

# %% [markdown]
# ### Test set

# %%
lepostst16les = exp_pathle + "post_hnm_results/lesion_results/test16/froc_curve.png" 
Image.open(lepostst16les)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312A6F550>

# %% [markdown]
# # Liu

# %% [markdown]
# ## Patch level results

# %%
exp_pathli = "/home/ubuntu/repath/experiments/liu/"

li = "inference_results/"

# %% [markdown]
# ### Validation set

# %%
livalid = exp_pathli + li + "valid16mean/patch_summaries/" 

liv_cm = livalid + "confidence_matrix.png"

Image.open(liv_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312A6F908>

# %%
liv_cur = livalid + "patch_pr_curve.png"
Image.open(liv_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312A6F8D0>

# %% [markdown]
# ### Test set

# %%
litest = exp_pathli + li + "test16mean/patch_summaries/" 

lit_cm = litest + "confidence_matrix.png"

Image.open(lit_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312A6FD30>

# %%
lit_cur = litest + "patch_pr_curve.png"
Image.open(lit_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312A6FEF0>

# %% [markdown]
# ## Slide level results

# %% [markdown]
# ### Validation set

# %%
livalsl = exp_pathli + li + "slide_results16_valid/" 

livsl_cm = livalsl + "confidence_matrix.png"

Image.open(livsl_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312A7C438>

# %%
livsl_cur = livalsl + "slide_pr_curve.png"
Image.open(livsl_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312A7C5F8>

# %% [markdown]
# ### Test set

# %%
litstsl = exp_pathli + li + "slide_results16_test/" 

litsl_cm = litstsl + "confidence_matrix.png"

Image.open(litsl_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7F5312A7CA20>

# %%
litsl_cur = litstsl + "slide_pr_curve.png"
Image.open(litsl_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312A7CC50>

# %% [markdown]
# ## Lesion level results

# %% [markdown]
# ### Validation set

# %%
lival16les = exp_pathli + "inference_results/lesion_results/valid16/froc_curve.png" 
Image.open(lival16les)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312A7CF60>

# %% [markdown]
# ### Test set

# %%
litst16les = exp_pathli + "inference_results/lesion_results/test16/froc_curve.png" 
Image.open(litst16les)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7F5312A832E8>
