# %% [markdown]
# # Wang

# %% [markdown]
# ## Patch level results

# %%
exp_pathw = "/home/ubuntu/repath/experiments/wang/"

# %% [markdown]
# ### Pre hard negative mining

# %%
wpre = "pre_hnm_results/patch_summaries/"

# %% [markdown]
# #### Validation set

# %%
from PIL import Image

wvalidpr = exp_pathw + wpre + "valid16/" 

wprev_cm = wvalidpr + "confidence_matrix.png"

Image.open(wprev_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA86EDB00>

# %%
wprev_cur = wvalidpr + "patch_pr_curve.png"
Image.open(wprev_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA80E8BE0>

# %% [markdown]
# #### Test set

# %%
wtestpr = exp_pathw + wpre + "test16/" 

wpret_cm = wtestpr + "confidence_matrix.png"

Image.open(wprev_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA8106128>

# %%
wpret_cur = wtestpr + "patch_pr_curve.png"
Image.open(wpret_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA8106390>

# %% [markdown]
# ### Post hard negative mining

# %%
wpost = "post_hnm_results/patch_summaries/"

# %% [markdown]
# #### Validation set

# %%
wvalidpo = exp_pathw + wpost + "valid16/" 

wpostv_cm = wvalidpo + "confidence_matrix.png"

Image.open(wpostv_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA8106080>

# %%
wpostv_cur = wvalidpo + "patch_pr_curve.png"
Image.open(wpostv_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA81065F8>

# %% [markdown]
# #### Test set

# %%
wtestpo = exp_pathw + wpost + "test16/" 

wpostt_cm = wtestpo + "confidence_matrix.png"

Image.open(wpostt_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA8106908>

# %%
wpostt_cur = wtestpo + "patch_pr_curve.png"
Image.open(wpostt_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA8106C88>

# %% [markdown]
# ## Slide level results

# %% [markdown]
# ### Pre hard negative mining

# %% [markdown]
# #### Validation Set

# %%
wpreval16 = exp_pathw + "pre_hnm_results/slide_results16_valid/" 

wprevalsl16_cm = wpreval16 + "confidence_matrix.png"

Image.open(wprevalsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA8106F98>

# %%
wprevalsl16_cur = wpreval16 + "slide_pr_curve.png"

Image.open(wprevalsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA8111EF0>

# %% [markdown]
# #### Test Set

# %%
wpretest16 = exp_pathw + "pre_hnm_results/slide_results16_test/" 

wpretestsl16_cm = wpretest16 + "confidence_matrix.png"

Image.open(wpretestsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA8111710>

# %%
wpretestsl16_cur = wpretest16 + "slide_pr_curve.png"

Image.open(wpretestsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA8111518>

# %% [markdown]
# ### Post hard negative mining

# %% [markdown]
# #### Validation Set

# %%
wposval16 = exp_pathw + "post_hnm_results/slide_results16_valid/" 

wposvalsl16_cm = wposval16 + "confidence_matrix.png"

Image.open(wposvalsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA8111F60>

# %%
wposvalsl16_cur = wposval16 + "slide_pr_curve.png"

Image.open(wposvalsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA8119240>

# %% [markdown]
# #### Test Set

# %%
wpostest16 = exp_pathw + "post_hnm_results/slide_results16_test/" 

wtestsl16_cm = wpostest16 + "confidence_matrix.png"

Image.open(wtestsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA81119B0>

# %%
wtestsl16_cur = wpostest16 + "slide_pr_curve.png"

Image.open(wtestsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA87044A8>

# %% [markdown]
# # Lee

# %% [markdown]
# ## Patch level results

# %%
exp_pathle = "/home/ubuntu/repath/experiments/lee/"

lepost = "post_hnm_results/patch_summaries/"

# %% [markdown]
# ### Validation set

# %% [markdown]
# #### Camelyon 16

# %%
levalidpo16 = exp_pathle + lepost + "valid16/" 

lepostv16_cm = levalidpo16 + "confidence_matrix.png"

Image.open(lepostv16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA8119278>

# %%
lepostv16_cur = levalidpo16 + "patch_pr_curve.png"
Image.open(lepostv16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA8111BA8>

# %% [markdown]
# #### Camelyon 17

# %%
levalidpo17 = exp_pathle + lepost + "valid17/" 

lepostv17_cm = levalidpo17 + "confidence_matrix.png"

Image.open(lepostv17_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA81194E0>

# %%
lepostv17_cur = levalidpo17 + "patch_pr_curve.png"
Image.open(lepostv17_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA8119390>

# %% [markdown]
# #### Combined camelyon 16 and 17

# %%
levalidpo1617 = exp_pathle + lepost + "valid1617/" 

lepostv1617_cm = levalidpo1617 + "confidence_matrix.png"

Image.open(lepostv1617_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA81197B8>

# %%
lepostv1617_cur = levalidpo1617 + "patch_pr_curve.png"
Image.open(lepostv1617_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA8119668>

# %% [markdown]
# ### Test set

# %% [markdown]
# #### Camelyon 16

# %%
letestpo16 = exp_pathle + lepost + "test16/" 

lepret16_cm = letestpo16 + "confidence_matrix.png"

Image.open(lepret16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA8119A58>

# %%
lepostt16_cur = letestpo16 + "patch_pr_curve.png"
Image.open(lepostt16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA8119940>

# %% [markdown]
# #### camelyon 17 - no annotations for test images for camelyon 17 so no patch level comparisons

# %% [markdown]
# #### Combined camelyon 16 and 17 - no annotations for test images for camelyon 17 so no combined patch level comparisons

# %% [markdown]
# ## Slide level results

# %% [markdown]
# ### Validation set

# %% [markdown]
# #### camelyon 16

# %%
levalsl16 = exp_pathle + "post_hnm_results/slide_results16_valid/"

levalsl16_cm = levalsl16 + "confidence_matrix.png"

Image.open(levalsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA8119C88>

# %%
levalsl16_cur = levalsl16 + "slide_pr_curve.png"

Image.open(levalsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA8119B70>

# %% [markdown]
# #### camelyon 17

# %%
levalsl17 = exp_pathle + "post_hnm_results/slide_results17_valid/"

levalsl17_cm = levalsl17 + "confidence_matrix.png"

Image.open(levalsl17_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA8119EF0>

# %% [markdown]
# No PR curve as multi class

# %% [markdown]
# ### Test Set

# %% [markdown]
# #### Camelyon 16

# %%
letestsl16 = exp_pathle + "post_hnm_results/slide_results16_test/"

letestsl16_cm = letestsl16 + "confidence_matrix.png"

Image.open(letestsl16_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA80AC0B8>

# %%
letestsl16_cur = letestsl16 + "slide_pr_curve.png"

Image.open(letestsl16_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA80AC128>

# %% [markdown]
# #### Camelyon 17

# %%
letestsl17 = exp_pathle + "post_hnm_results/slide_results17_test/"

letestsl17_cm = letestsl17 + "confidence_matrix.png"

Image.open(letestsl17_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA80AC320>

# %% [markdown]
# No PR curve as multi class

# %% [markdown]
# ## Patient level results

# %% [markdown]
# ### Validation set

# %%
levalpat17 = exp_pathle + "post_hnm_results/patient_results17_valid/"

levalpat17_cm = levalpat17 + "confidence_matrix.png"

Image.open(levalpat17_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA80AC630>

# %% [markdown]
# ### Test set

# %%
letstpat17 = exp_pathle + "post_hnm_results/patient_results17_test/"

letstpat17_cm = letstpat17 + "confidence_matrix.png"

Image.open(letstpat17_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA80AC978>

# %% [markdown]
# # Liu

# %% [markdown]
# ## Patch level results

# %%
exp_pathli = "/home/ubuntu/repath/experiments/liu/"

li = "inference_results/"

# %% [markdown]
# ### Validation set

# %%
livalid = exp_pathli + li + "valid16mean/patch_summaries/" 

liv_cm = livalid + "confidence_matrix.png"

Image.open(liv_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA80B6C18>

# %%
liv_cur = livalid + "patch_pr_curve.png"
Image.open(liv_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA80B6DA0>

# %% [markdown]
# ### Test set

# %%
litest = exp_pathli + li + "test16mean/patch_summaries/" 

lit_cm = litest + "confidence_matrix.png"

Image.open(lit_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA80BD320>

# %%
lit_cur = litest + "patch_pr_curve.png"
Image.open(lit_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA80BD4E0>

# %% [markdown]
# ## Slide level results

# %% [markdown]
# ### Validation set

# %%
livalsl = exp_pathli + li + "slide_results16_valid/" 

livsl_cm = livalsl + "confidence_matrix.png"

Image.open(livsl_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA80BD9B0>

# %%
livsl_cur = livalsl + "slide_pr_curve.png"
Image.open(livsl_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA80BDB00>

# %% [markdown]
# ### Test set

# %%
litstsl = exp_pathli + li + "slide_results16_test/" 

litsl_cm = litstsl + "confidence_matrix.png"

Image.open(litsl_cm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7EFEA80C6048>

# %%
litsl_cur = livalsl + "slide_pr_curve.png"
Image.open(litsl_cur)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x7EFEA80C6208>
