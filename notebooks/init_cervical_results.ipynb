# %% [markdown]
# # Initial cervical results

# %% [markdown]
# ## patch size = 256, no of patches ~ 7500

# %% [markdown]
# 256 x 256 patches about 7500 of each class. Number limited to ~7500 as that is the number of patches of the rarest class

# %%
from PIL import Image
from repath.utils.paths import project_root
Image.open(project_root() / 'experiments' / 'cervical1' / 'patch_results' / 'patch_summaries' / 'valid' / 'confidence_matrix.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7FC6F794AF98>

# %%
# Out:
# [[159173]
#  [  5270]
#  [  3050]
#  [ 55392]]
# array([[66.5,  9.6, 15.1,  8.8],
#        [14.9, 56.7, 24.6,  3.8],
#        [ 6.5, 34.3, 57.4,  1.8],
#        [17.7, 10. , 17.2, 55.1]])

# %% [markdown]
# ## patch size = 128, no of patches ~ 50000

# %% [markdown]
# reduce patch size to 128 by 128 to increase number of patches. 50000 patches for normal and malignant, 46000 for low grade and 26000 for high grade

# %%
Image.open(project_root() / 'experiments' / 'cervical4' / 'patch_results' / 'patch_summaries' / 'valid' / 'confidence_matrix.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7FC6F4050278>

# %% [markdown]
# ## patch size = 128, no of patches ~ 800000

# %% [markdown]
# Try to maximise number of patches by using overlapping patches. 128 by 128 pathches, grid stride 32, 800000 for normal and malignant, 741894 for low grade and 410641 for high grade

# %%
Image.open(project_root() / 'experiments' / 'cervical_debug' / 'stride32_results' / 'patch_summaries' / 'valid' / 'confidence_matrix.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7FC6F4050358>

# %% [markdown]
# ## patch size 256, no of patches ~ 50000

# %% [markdown]
# patch size labels at grid of 128 by 128 with stide of 128, but border of 128 added. 50000 patches for normal and malignant, 46000 for low grade and 26000 for high grade. Labels based on centre of patch.

# %%
Image.open(project_root() / 'experiments' / 'cervical_256' / 'patch256_results' / 'patch_summaries' / 'valid' / 'confidence_matrix.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800 at 0x7FC6F4050400>

# %%
# Out:
# array([[66.5,  9.6, 15.1,  8.8],
#        [14.9, 56.7, 24.6,  3.8],
#        [ 6.5, 34.3, 57.4,  1.8],
#        [17.7, 10. , 17.2, 55.1]])

# %%
# Out:
# array([[71.6,  4.9,  8.1, 15.4],
#        [12.7, 57.7, 22.3,  7.3],
#        [ 9. , 32.1, 49.3,  9.6],
#        [12.1,  4.2,  9.5, 74.1]])

# %%
# Out:
# (3, 2, 4)

# %%
# Out:
# [array(['a', 'g', 'm', 's'], dtype='<U1'),
#  array(['b', 'h', 'n', 't'], dtype='<U1'),
#  array(['c', 'i', 'o', 'u'], dtype='<U1'),
#  array(['d', 'j', 'p', 'v'], dtype='<U1'),
#  array(['e', 'k', 'q', 'w'], dtype='<U1'),
#  array(['f', 'l', 'r', 'x'], dtype='<U1')]

# %%
# Out:
# (4, 6)

# %%
# Out:
# array([ True, False,  True,  True,  True,  True])

# %%
# Out:
# (6,)

# %%
# Out:
# (4, 5)
