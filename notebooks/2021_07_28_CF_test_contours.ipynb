# %%
from repath.utils.paths import project_root

filenm = project_root() / 'experiments' / 'coins.jpeg'

# %%
from PIL import Image

Image.open(filenm)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=600x442 at 0x7F9A504F2160>

# %%
import numpy as np
import cv2

im = cv2.imread(str(filenm))

# %%
imgray = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(imgray, 127, 255, 0)
contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# %%
print(type(im), im.dtype)
# Out:
# <class 'numpy.ndarray'> uint8

# %%
print(type(contours))
# Out:
# <class 'list'>

# %%
print(contours)
# Out:
# [array([[[  0,   0]],
#
#        [[  0, 441]],
#
#        [[599, 441]],
#
#        [[599,   0]]], dtype=int32), array([[[304, 424]],
#
#        [[305, 423]],
#
#        [[306, 424]],
#
#        [[305, 425]]], dtype=int32), array([[[306, 423]],
#
#        [[307, 422]],
#
#        [[310, 422]],
#
#        [[311, 423]],
#
#        [[310, 424]],
#
#        [[307, 424]]], dtype=int32), array([[[312, 422]],
#
#        [[313, 421]],
#
#        [[314, 422]],
#
#        [[313, 423]]], dtype=int32), array([[[301, 422]],
#
#        [[302, 421]],
#
#        [[303, 421]],
#
#        [[304, 422]],
#
#        [[303, 423]],
#
#        [[302, 423]]], dtype=int32), array([[[298, 422]],
#
#        [[299, 421]],
#
#        [[300, 421]],
#
#        [[301, 422]],
#
#        [[300, 423]],
#
#        [[299, 423]]], dtype=int32), array([[[316, 421]],
#
#        [[317, 420]],
#
#        [[318, 420]],
#
#        [[319, 421]],
#
#        [[318, 422]],
#
#        [[317, 422]]], dtype=int32), array([[[308, 421]],
#
#        [[309, 420]],
#
#        [[310, 421]],
#
#        [[309, 422]]], dtype=int32), array([[[319, 420]],
#
#        [[320, 419]],
#
#        [[321, 420]],
#
#        [[320, 421]]], dtype=int32), array([[[311, 420]],
#
#        [[312, 419]],
#
#        [[314, 419]],
#
#        [[315, 420]],
#
#        [[314, 421]],
#
#        [[312, 421]]], dtype=int32), array([[[315, 419]],
#
#        [[316, 418]],
#
#        [[317, 418]],
#
#        [[318, 419]],
#
#        [[317, 420]],
#
#        [[316, 420]]], dtype=int32), array([[[317, 418]],
#
#        [[318, 417]],
#
#        [[319, 417]],
#
#        [[320, 418]],
#
#        [[319, 419]],
#
#        [[318, 419]]], dtype=int32), array([[[327, 417]],
#
#        [[328, 416]],
#
#        [[329, 417]],
#
#        [[328, 418]]], dtype=int32), array([[[320, 417]],
#
#        [[321, 416]],
#
#        [[322, 416]],
#
#        [[323, 417]],
#
#        [[322, 418]],
#
#        [[321, 418]]], dtype=int32), array([[[323, 416]],
#
#        [[324, 415]],
#
#        [[325, 416]],
#
#        [[324, 417]]], dtype=int32), array([[[264, 416]],
#
#        [[265, 415]],
#
#        [[266, 416]],
#
#        [[265, 417]]], dtype=int32), array([[[330, 415]],
#
#        [[331, 414]],
#
#        [[332, 415]],
#
#        [[331, 416]]], dtype=int32), array([[[324, 415]],
#
#        [[325, 414]],
#
#        [[326, 414]],
#
#        [[327, 415]],
#
#        [[326, 416]],
#
#        [[325, 416]]], dtype=int32), array([[[262, 415]],
#
#        [[263, 414]],
#
#        [[264, 415]],
#
#        [[263, 416]]], dtype=int32), array([[[260, 414]],
#
#        [[261, 413]],
#
#        [[262, 414]],
#
#        [[261, 415]]], dtype=int32), array([[[334, 413]],
#
#        [[335, 412]],
#
#        [[336, 413]],
#
#        [[335, 414]]], dtype=int32), array([[[258, 413]],
#
#        [[259, 412]],
#
#        [[260, 413]],
#
#        [[259, 414]]], dtype=int32), array([[[255, 411]],
#
#        [[256, 410]],
#
#        [[257, 410]],
#
#        [[258, 411]],
#
#        [[258, 412]],
#
#        [[257, 413]]], dtype=int32), array([[[250, 407]],
#
#        [[251, 406]],
#
#        [[252, 407]],
#
#        [[251, 408]]], dtype=int32), array([[[121, 406]],
#
#        [[122, 405]],
#
#        [[128, 405]],
#
#        [[129, 406]],
#
#        [[130, 406]],
#
#        [[131, 407]],
#
#        [[130, 408]],
#
#        [[129, 408]],
#
#        [[128, 409]],
#
#        [[126, 407]],
#
#        [[122, 407]]], dtype=int32), array([[[113, 406]],
#
#        [[114, 405]],
#
#        [[117, 405]],
#
#        [[118, 406]],
#
#        [[117, 407]],
#
#        [[114, 407]]], dtype=int32), array([[[340, 405]],
#
#        [[341, 404]],
#
#        [[342, 405]],
#
#        [[341, 406]]], dtype=int32), array([[[243, 405]],
#
#        [[244, 404]],
#
#        [[247, 407]],
#
#        [[246, 408]],
#
#        [[245, 408]],
#
#        [[243, 406]]], dtype=int32), array([[[111, 405]],
#
#        [[112, 404]],
#
#        [[113, 404]],
#
#        [[114, 405]],
#
#        [[113, 406]],
#
#        [[112, 406]]], dtype=int32), array([[[341, 404]],
#
#        [[342, 403]],
#
#        [[343, 404]],
#
#        [[342, 405]]], dtype=int32), array([[[246, 404]],
#
#        [[247, 403]],
#
#        [[248, 403]],
#
#        [[250, 405]],
#
#        [[250, 406]],
#
#        [[249, 407]]], dtype=int32), array([[[242, 404]],
#
#        [[243, 403]],
#
#        [[244, 404]],
#
#        [[243, 405]]], dtype=int32), array([[[342, 403]],
#
#        [[343, 402]],
#
#        [[344, 403]],
#
#        [[343, 404]]], dtype=int32), array([[[245, 403]],
#
#        [[246, 402]],
#
#        [[247, 403]],
#
#        [[246, 404]]], dtype=int32), array([[[241, 403]],
#
#        [[242, 402]],
#
#        [[243, 403]],
#
#        [[242, 404]]], dtype=int32), array([[[343, 402]],
#
#        [[344, 401]],
#
#        [[345, 402]],
#
#        [[344, 403]]], dtype=int32), array([[[244, 402]],
#
#        [[245, 401]],
#
#        [[246, 402]],
#
#        [[245, 403]]], dtype=int32), array([[[240, 402]],
#
#        [[241, 401]],
#
#        [[242, 402]],
#
#        [[241, 403]]], dtype=int32), array([[[344, 401]],
#
#        [[345, 400]],
#
#        [[346, 401]],
#
#        [[345, 402]]], dtype=int32), array([[[243, 401]],
#
#        [[244, 400]],
#
#        [[245, 401]],
#
#        [[244, 402]]], dtype=int32), array([[[239, 401]],
#
#        [[240, 400]],
#
#        [[241, 401]],
#
#        [[240, 402]]], dtype=int32), array([[[136, 401]],
#
#        [[137, 400]],
#
#        [[138, 401]],
#
#        [[137, 402]]], dtype=int32), array([[[122, 401]],
#
#        [[123, 400]],
#
#        [[124, 401]],
#
#        [[125, 400]],
#
#        [[126, 400]],
#
#        [[127, 401]],
#
#        [[128, 401]],
#
#        [[129, 402]],
#
#        [[130, 402]],
#
#        [[131, 403]],
#
#        [[135, 403]],
#
#        [[136, 404]],
#
#        [[134, 406]],
#
#        [[133, 405]],
#
#        [[129, 405]],
#
#        [[128, 404]],
#
#        [[114, 404]],
#
#        [[113, 403]],
#
#        [[114, 402]],
#
#        [[117, 402]],
#
#        [[118, 401]],
#
#        [[119, 402]],
#
#        [[120, 401]],
#
#        [[121, 401]],
#
#        [[122, 402]]], dtype=int32), array([[[345, 400]],
#
#        [[346, 399]],
#
#        [[347, 400]],
#
#        [[346, 401]]], dtype=int32), array([[[103, 400]],
#
#        [[104, 399]],
#
#        [[105, 400]],
#
#        [[105, 401]],
#
#        [[104, 402]],
#
#        [[103, 401]]], dtype=int32), array([[[346, 399]],
#
#        [[347, 398]],
#
#        [[348, 399]],
#
#        [[347, 400]]], dtype=int32), array([[[129, 399]],
#
#        [[130, 398]],
#
#        [[131, 399]],
#
#        [[130, 400]]], dtype=int32), array([[[100, 399]],
#
#        [[101, 398]],
#
#        [[102, 399]],
#
#        [[101, 400]]], dtype=int32), array([[[347, 398]],
#
#        [[348, 397]],
#
#        [[349, 398]],
#
#        [[348, 399]]], dtype=int32), array([[[345, 398]],
#
#        [[346, 397]],
#
#        [[347, 398]],
#
#        [[346, 399]]], dtype=int32), array([[[132, 398]],
#
#        [[133, 397]],
#
#        [[134, 398]],
#
#        [[133, 399]]], dtype=int32), array([[[412, 397]],
#
#        [[413, 396]],
#
#        [[414, 396]],
#
#        [[418, 400]],
#
#        [[417, 401]],
#
#        [[416, 401]]], dtype=int32), array([[[346, 397]],
#
#        [[347, 396]],
#
#        [[348, 397]],
#
#        [[347, 398]]], dtype=int32), array([[[123, 397]],
#
#        [[124, 396]],
#
#        [[126, 396]],
#
#        [[127, 397]],
#
#        [[126, 398]],
#
#        [[125, 398]],
#
#        [[124, 399]],
#
#        [[122, 399]],
#
#        [[121, 400]],
#
#        [[118, 400]],
#
#        [[117, 401]],
#
#        [[115, 401]],
#
#        [[114, 402]],
#
#        [[112, 402]],
#
#        [[112, 403]],
#
#        [[111, 404]],
#
#        [[110, 403]],
#
#        [[109, 403]],
#
#        [[108, 402]],
#
#        [[107, 403]],
#
#        [[106, 403]],
#
#        [[105, 402]],
#
#        [[106, 401]],
#
#        [[106, 400]],
#
#        [[107, 399]],
#
#        [[108, 399]],
#
#        [[109, 400]],
#
#        [[110, 399]],
#
#        [[111, 400]],
#
#        [[112, 400]],
#
#        [[113, 399]],
#
#        [[115, 399]],
#
#        [[116, 398]],
#
#        [[119, 398]],
#
#        [[120, 397]]], dtype=int32), array([[[113, 397]],
#
#        [[114, 396]],
#
#        [[115, 397]],
#
#        [[114, 398]]], dtype=int32), array([[[235, 396]],
#
#        [[236, 395]],
#
#        [[237, 396]],
#
#        [[236, 397]]], dtype=int32), array([[[135, 396]],
#
#        [[136, 395]],
#
#        [[137, 395]],
#
#        [[138, 396]],
#
#        [[137, 397]],
#
#        [[136, 397]]], dtype=int32), array([[[104, 396]],
#
#        [[105, 395]],
#
#        [[106, 396]],
#
#        [[105, 397]]], dtype=int32), array([[[349, 394]],
#
#        [[351, 396]],
#
#        [[349, 398]],
#
#        [[347, 396]]], dtype=int32), array([[[164, 395]],
#
#        [[165, 394]],
#
#        [[166, 395]],
#
#        [[165, 396]]], dtype=int32), array([[[140, 394]],
#
#        [[141, 394]],
#
#        [[142, 395]],
#
#        [[141, 396]],
#
#        [[141, 398]],
#
#        [[140, 399]],
#
#        [[139, 398]],
#
#        [[140, 399]],
#
#        [[139, 400]],
#
#        [[136, 400]],
#
#        [[136, 401]],
#
#        [[135, 402]],
#
#        [[133, 402]],
#
#        [[131, 400]],
#
#        [[132, 399]],
#
#        [[134, 399]],
#
#        [[136, 397]],
#
#        [[137, 397]]], dtype=int32), array([[[137, 395]],
#
#        [[138, 394]],
#
#        [[139, 395]],
#
#        [[138, 396]]], dtype=int32), array([[[129, 395]],
#
#        [[130, 394]],
#
#        [[132, 394]],
#
#        [[133, 395]],
#
#        [[132, 396]],
#
#        [[131, 396]],
#
#        [[130, 397]],
#
#        [[127, 397]],
#
#        [[126, 396]],
#
#        [[127, 395]]], dtype=int32), array([[[108, 394]],
#
#        [[110, 394]],
#
#        [[111, 395]],
#
#        [[112, 395]],
#
#        [[113, 396]],
#
#        [[112, 397]],
#
#        [[109, 397]],
#
#        [[108, 398]],
#
#        [[106, 396]]], dtype=int32), array([[[350, 394]],
#
#        [[351, 393]],
#
#        [[352, 394]],
#
#        [[351, 395]]], dtype=int32), array([[[152, 394]],
#
#        [[153, 393]],
#
#        [[154, 394]],
#
#        [[153, 395]]], dtype=int32), array([[[141, 394]],
#
#        [[142, 393]],
#
#        [[143, 393]],
#
#        [[144, 394]],
#
#        [[144, 396]],
#
#        [[143, 397]],
#
#        [[142, 397]],
#
#        [[141, 396]],
#
#        [[142, 395]]], dtype=int32), array([[[116, 394]],
#
#        [[117, 393]],
#
#        [[118, 394]],
#
#        [[117, 395]]], dtype=int32), array([[[ 94, 394]],
#
#        [[ 95, 393]],
#
#        [[ 96, 394]],
#
#        [[ 95, 395]]], dtype=int32), array([[[ 85, 394]],
#
#        [[ 86, 393]],
#
#        [[ 87, 394]],
#
#        [[ 86, 395]]], dtype=int32), array([[[143, 393]],
#
#        [[144, 392]],
#
#        [[145, 393]],
#
#        [[144, 394]]], dtype=int32), array([[[120, 393]],
#
#        [[121, 392]],
#
#        [[122, 393]],
#
#        [[121, 394]]], dtype=int32), array([[[ 84, 393]],
#
#        [[ 85, 392]],
#
#        [[ 86, 393]],
#
#        [[ 85, 394]]], dtype=int32), array([[[136, 392]],
#
#        [[137, 391]],
#
#        [[139, 391]],
#
#        [[140, 392]],
#
#        [[139, 393]],
#
#        [[138, 393]],
#
#        [[137, 394]],
#
#        [[136, 394]],
#
#        [[135, 395]],
#
#        [[133, 395]],
#
#        [[132, 394]],
#
#        [[133, 393]],
#
#        [[134, 393]],
#
#        [[135, 392]]], dtype=int32), array([[[103, 392]],
#
#        [[104, 391]],
#
#        [[105, 392]],
#
#        [[104, 393]]], dtype=int32), array([[[ 83, 392]],
#
#        [[ 84, 391]],
#
#        [[ 85, 392]],
#
#        [[ 84, 393]]], dtype=int32), array([[[353, 390]],
#
#        [[354, 391]],
#
#        [[354, 392]],
#
#        [[352, 394]],
#
#        [[351, 393]],
#
#        [[351, 392]]], dtype=int32), array([[[139, 391]],
#
#        [[140, 390]],
#
#        [[141, 390]],
#
#        [[142, 391]],
#
#        [[141, 392]],
#
#        [[140, 392]]], dtype=int32), array([[[104, 391]],
#
#        [[105, 390]],
#
#        [[106, 391]],
#
#        [[105, 392]]], dtype=int32), array([[[123, 390]],
#
#        [[124, 389]],
#
#        [[125, 390]],
#
#        [[125, 391]],
#
#        [[124, 392]],
#
#        [[121, 392]],
#
#        [[120, 391]],
#
#        [[121, 390]]], dtype=int32), array([[[119, 390]],
#
#        [[120, 389]],
#
#        [[121, 390]],
#
#        [[120, 391]]], dtype=int32), array([[[ 95, 390]],
#
#        [[ 96, 389]],
#
#        [[ 97, 390]],
#
#        [[ 96, 391]]], dtype=int32), array([[[164, 389]],
#
#        [[165, 388]],
#
#        [[166, 388]],
#
#        [[167, 389]],
#
#        [[166, 390]],
#
#        [[166, 392]],
#
#        [[165, 393]],
#
#        [[164, 392]]], dtype=int32), array([[[106, 389]],
#
#        [[107, 388]],
#
#        [[108, 389]],
#
#        [[107, 390]]], dtype=int32), array([[[ 89, 389]],
#
#        [[ 90, 388]],
#
#        [[ 91, 389]],
#
#        [[ 90, 390]]], dtype=int32), array([[[ 81, 389]],
#
#        [[ 82, 388]],
#
#        [[ 83, 389]],
#
#        [[ 82, 390]]], dtype=int32), array([[[123, 388]],
#
#        [[124, 387]],
#
#        [[125, 387]],
#
#        [[126, 388]],
#
#        [[125, 389]],
#
#        [[124, 389]]], dtype=int32), array([[[171, 387]],
#
#        [[172, 386]],
#
#        [[173, 387]],
#
#        [[172, 388]]], dtype=int32), array([[[165, 387]],
#
#        [[166, 386]],
#
#        [[167, 387]],
#
#        [[166, 388]]], dtype=int32), array([[[160, 387]],
#
#        [[161, 386]],
#
#        [[162, 386]],
#
#        [[163, 387]],
#
#        [[164, 387]],
#
#        [[165, 388]],
#
#        [[163, 390]],
#
#        [[162, 389]],
#
#        [[161, 389]],
#
#        [[160, 388]]], dtype=int32), array([[[125, 387]],
#
#        [[126, 386]],
#
#        [[127, 387]],
#
#        [[126, 388]]], dtype=int32), array([[[103, 387]],
#
#        [[104, 386]],
#
#        [[105, 387]],
#
#        [[105, 389]],
#
#        [[104, 390]],
#
#        [[103, 389]]], dtype=int32), array([[[356, 385]],
#
#        [[357, 386]],
#
#        [[357, 387]],
#
#        [[356, 388]],
#
#        [[356, 389]],
#
#        [[354, 391]],
#
#        [[353, 390]],
#
#        [[353, 389]],
#
#        [[354, 388]],
#
#        [[354, 387]]], dtype=int32), array([[[232, 386]],
#
#        [[233, 385]],
#
#        [[234, 386]],
#
#        [[234, 387]],
#
#        [[233, 388]],
#
#        [[232, 387]]], dtype=int32), array([[[172, 386]],
#
#        [[173, 385]],
#
#        [[174, 385]],
#
#        [[175, 386]],
#
#        [[174, 387]],
#
#        [[173, 387]]], dtype=int32), array([[[170, 386]],
#
#        [[171, 385]],
#
#        [[172, 386]],
#
#        [[171, 387]]], dtype=int32), array([[[137, 386]],
#
#        [[138, 385]],
#
#        [[139, 386]],
#
#        [[138, 387]]], dtype=int32), array([[[100, 386]],
#
#        [[101, 385]],
#
#        [[102, 386]],
#
#        [[101, 387]]], dtype=int32), array([[[ 92, 386]],
#
#        [[ 93, 385]],
#
#        [[ 94, 385]],
#
#        [[ 95, 386]],
#
#        [[ 94, 387]],
#
#        [[ 93, 387]]], dtype=int32), array([[[139, 385]],
#
#        [[140, 384]],
#
#        [[141, 385]],
#
#        [[140, 386]]], dtype=int32), array([[[ 89, 385]],
#
#        [[ 90, 384]],
#
#        [[ 91, 385]],
#
#        [[ 90, 386]]], dtype=int32), array([[[356, 384]],
#
#        [[357, 383]],
#
#        [[358, 384]],
#
#        [[358, 385]],
#
#        [[357, 386]],
#
#        [[356, 385]]], dtype=int32), array([[[231, 384]],
#
#        [[232, 383]],
#
#        [[233, 384]],
#
#        [[233, 385]],
#
#        [[232, 386]],
#
#        [[231, 385]]], dtype=int32), array([[[149, 384]],
#
#        [[150, 383]],
#
#        [[151, 384]],
#
#        [[150, 385]]], dtype=int32), array([[[143, 384]],
#
#        [[144, 383]],
#
#        [[145, 383]],
#
#        [[146, 384]],
#
#        [[146, 385]],
#
#        [[145, 386]]], dtype=int32), array([[[ 97, 384]],
#
#        [[ 98, 383]],
#
#        [[ 99, 384]],
#
#        [[ 98, 385]]], dtype=int32), array([[[ 94, 384]],
#
#        [[ 95, 383]],
#
#        [[ 96, 384]],
#
#        [[ 95, 385]]], dtype=int32), array([[[357, 383]],
#
#        [[358, 382]],
#
#        [[359, 383]],
#
#        [[358, 384]]], dtype=int32), array([[[230, 383]],
#
#        [[231, 382]],
#
#        [[232, 383]],
#
#        [[231, 384]]], dtype=int32), array([[[118, 383]],
#
#        [[119, 382]],
#
#        [[120, 383]],
#
#        [[119, 384]]], dtype=int32), array([[[108, 383]],
#
#        [[109, 382]],
#
#        [[110, 383]],
#
#        [[109, 384]]], dtype=int32), array([[[ 95, 383]],
#
#        [[ 96, 382]],
#
#        [[ 97, 383]],
#
#        [[ 96, 384]]], dtype=int32), array([[[ 92, 383]],
#
#        [[ 93, 382]],
#
#        [[ 94, 383]],
#
#        [[ 94, 384]],
#
#        [[ 93, 385]],
#
#        [[ 92, 384]]], dtype=int32), array([[[101, 382]],
#
#        [[102, 381]],
#
#        [[103, 382]],
#
#        [[104, 382]],
#
#        [[105, 383]],
#
#        [[108, 383]],
#
#        [[109, 384]],
#
#        [[110, 383]],
#
#        [[111, 383]],
#
#        [[112, 384]],
#
#        [[110, 386]],
#
#        [[108, 386]],
#
#        [[107, 387]],
#
#        [[106, 386]],
#
#        [[106, 385]],
#
#        [[105, 386]],
#
#        [[104, 385]],
#
#        [[103, 385]],
#
#        [[102, 384]],
#
#        [[100, 384]],
#
#        [[ 99, 383]],
#
#        [[100, 382]]], dtype=int32), array([[[159, 381]],
#
#        [[160, 380]],
#
#        [[161, 381]],
#
#        [[162, 381]],
#
#        [[163, 380]],
#
#        [[164, 381]],
#
#        [[166, 381]],
#
#        [[167, 382]],
#
#        [[168, 382]],
#
#        [[170, 384]],
#
#        [[170, 385]],
#
#        [[169, 386]],
#
#        [[167, 386]],
#
#        [[166, 385]],
#
#        [[161, 385]],
#
#        [[160, 386]],
#
#        [[158, 386]],
#
#        [[157, 387]],
#
#        [[156, 386]],
#
#        [[155, 387]],
#
#        [[153, 387]],
#
#        [[154, 387]],
#
#        [[155, 388]],
#
#        [[154, 389]],
#
#        [[152, 389]],
#
#        [[151, 388]],
#
#        [[149, 388]],
#
#        [[148, 389]],
#
#        [[147, 389]],
#
#        [[146, 390]],
#
#        [[145, 390]],
#
#        [[144, 391]],
#
#        [[143, 391]],
#
#        [[142, 390]],
#
#        [[144, 388]],
#
#        [[145, 388]],
#
#        [[146, 387]],
#
#        [[147, 387]],
#
#        [[148, 386]],
#
#        [[150, 386]],
#
#        [[151, 385]],
#
#        [[153, 385]],
#
#        [[154, 384]],
#
#        [[155, 384]],
#
#        [[154, 384]],
#
#        [[153, 383]],
#
#        [[154, 382]],
#
#        [[155, 382]],
#
#        [[156, 381]],
#
#        [[157, 381]],
#
#        [[158, 382]],
#
#        [[159, 382]]], dtype=int32), array([[[ 82, 381]],
#
#        [[ 83, 380]],
#
#        [[ 84, 381]],
#
#        [[ 83, 382]]], dtype=int32), array([[[163, 380]],
#
#        [[164, 379]],
#
#        [[165, 380]],
#
#        [[164, 381]]], dtype=int32), array([[[ 84, 380]],
#
#        [[ 85, 379]],
#
#        [[ 86, 380]],
#
#        [[ 85, 381]]], dtype=int32), array([[[166, 379]],
#
#        [[167, 378]],
#
#        [[168, 379]],
#
#        [[167, 380]]], dtype=int32), array([[[157, 379]],
#
#        [[158, 378]],
#
#        [[159, 379]],
#
#        [[158, 380]]], dtype=int32), array([[[228, 378]],
#
#        [[229, 377]],
#
#        [[230, 378]],
#
#        [[229, 379]]], dtype=int32), array([[[164, 378]],
#
#        [[165, 377]],
#
#        [[166, 377]],
#
#        [[167, 378]],
#
#        [[166, 379]],
#
#        [[165, 379]]], dtype=int32), array([[[160, 378]],
#
#        [[161, 377]],
#
#        [[162, 378]],
#
#        [[161, 379]]], dtype=int32), array([[[ 82, 378]],
#
#        [[ 83, 377]],
#
#        [[ 84, 377]],
#
#        [[ 85, 378]],
#
#        [[ 85, 379]],
#
#        [[ 84, 380]],
#
#        [[ 83, 380]],
#
#        [[ 82, 379]]], dtype=int32), array([[[138, 377]],
#
#        [[139, 376]],
#
#        [[140, 377]],
#
#        [[139, 378]]], dtype=int32), array([[[134, 377]],
#
#        [[135, 376]],
#
#        [[136, 377]],
#
#        [[135, 378]]], dtype=int32), array([[[128, 377]],
#
#        [[129, 376]],
#
#        [[130, 377]],
#
#        [[130, 378]],
#
#        [[129, 379]],
#
#        [[128, 378]]], dtype=int32), array([[[117, 377]],
#
#        [[118, 376]],
#
#        [[119, 377]],
#
#        [[118, 378]]], dtype=int32), array([[[ 96, 377]],
#
#        [[ 97, 376]],
#
#        [[ 98, 377]],
#
#        [[ 97, 378]]], dtype=int32), array([[[ 80, 376]],
#
#        [[ 81, 375]],
#
#        [[ 82, 376]],
#
#        [[ 81, 377]]], dtype=int32), array([[[227, 375]],
#
#        [[228, 374]],
#
#        [[229, 375]],
#
#        [[228, 376]]], dtype=int32), array([[[180, 375]],
#
#        [[181, 374]],
#
#        [[182, 375]],
#
#        [[181, 376]]], dtype=int32), array([[[176, 375]],
#
#        [[177, 374]],
#
#        [[178, 375]],
#
#        [[177, 376]]], dtype=int32), array([[[161, 375]],
#
#        [[162, 374]],
#
#        [[163, 374]],
#
#        [[164, 375]],
#
#        [[165, 375]],
#
#        [[166, 376]],
#
#        [[164, 378]],
#
#        [[163, 378]],
#
#        [[161, 376]]], dtype=int32), array([[[157, 375]],
#
#        [[158, 374]],
#
#        [[159, 375]],
#
#        [[158, 376]]], dtype=int32), array([[[135, 375]],
#
#        [[136, 374]],
#
#        [[137, 374]],
#
#        [[138, 375]],
#
#        [[138, 377]],
#
#        [[137, 378]],
#
#        [[136, 377]],
#
#        [[136, 376]]], dtype=int32), array([[[119, 375]],
#
#        [[120, 374]],
#
#        [[121, 375]],
#
#        [[120, 376]]], dtype=int32), array([[[111, 375]],
#
#        [[112, 374]],
#
#        [[113, 375]],
#
#        [[112, 376]]], dtype=int32), array([[[103, 375]],
#
#        [[104, 374]],
#
#        [[105, 375]],
#
#        [[104, 376]]], dtype=int32), array([[[100, 375]],
#
#        [[101, 374]],
#
#        [[102, 375]],
#
#        [[101, 376]]], dtype=int32), array([[[ 97, 375]],
#
#        [[ 98, 374]],
#
#        [[ 99, 375]],
#
#        [[ 98, 376]]], dtype=int32), array([[[ 93, 375]],
#
#        [[ 94, 374]],
#
#        [[ 95, 375]],
#
#        [[ 95, 376]],
#
#        [[ 94, 377]],
#
#        [[ 93, 376]]], dtype=int32), array([[[ 85, 375]],
#
#        [[ 86, 374]],
#
#        [[ 87, 375]],
#
#        [[ 86, 376]]], dtype=int32), array([[[139, 374]],
#
#        [[140, 373]],
#
#        [[141, 374]],
#
#        [[140, 375]]], dtype=int32), array([[[137, 374]],
#
#        [[138, 373]],
#
#        [[139, 374]],
#
#        [[138, 375]]], dtype=int32), array([[[132, 373]],
#
#        [[133, 374]],
#
#        [[133, 378]],
#
#        [[132, 379]],
#
#        [[131, 378]],
#
#        [[131, 376]],
#
#        [[130, 375]]], dtype=int32), array([[[120, 374]],
#
#        [[121, 373]],
#
#        [[122, 374]],
#
#        [[121, 375]]], dtype=int32), array([[[226, 373]],
#
#        [[227, 372]],
#
#        [[228, 372]],
#
#        [[229, 373]],
#
#        [[228, 374]],
#
#        [[227, 374]]], dtype=int32), array([[[170, 373]],
#
#        [[171, 372]],
#
#        [[172, 373]],
#
#        [[171, 374]]], dtype=int32), array([[[140, 373]],
#
#        [[141, 372]],
#
#        [[142, 373]],
#
#        [[141, 374]]], dtype=int32), array([[[138, 373]],
#
#        [[139, 372]],
#
#        [[140, 373]],
#
#        [[139, 374]]], dtype=int32), array([[[136, 373]],
#
#        [[137, 372]],
#
#        [[138, 373]],
#
#        [[137, 374]]], dtype=int32), array([[[128, 373]],
#
#        [[129, 372]],
#
#        [[130, 373]],
#
#        [[129, 374]]], dtype=int32), array([[[122, 373]],
#
#        [[123, 372]],
#
#        [[124, 372]],
#
#        [[125, 373]],
#
#        [[124, 374]],
#
#        [[123, 374]]], dtype=int32), array([[[117, 373]],
#
#        [[118, 372]],
#
#        [[119, 373]],
#
#        [[119, 374]],
#
#        [[118, 375]],
#
#        [[117, 374]]], dtype=int32), array([[[107, 373]],
#
#        [[108, 372]],
#
#        [[109, 373]],
#
#        [[108, 374]]], dtype=int32), array([[[ 91, 373]],
#
#        [[ 92, 372]],
#
#        [[ 93, 373]],
#
#        [[ 93, 375]],
#
#        [[ 92, 376]],
#
#        [[ 91, 375]]], dtype=int32), array([[[361, 372]],
#
#        [[362, 371]],
#
#        [[363, 372]],
#
#        [[363, 373]],
#
#        [[362, 374]],
#
#        [[361, 373]]], dtype=int32), array([[[120, 372]],
#
#        [[121, 371]],
#
#        [[122, 371]],
#
#        [[123, 372]],
#
#        [[122, 373]],
#
#        [[121, 373]]], dtype=int32), array([[[ 93, 372]],
#
#        [[ 94, 371]],
#
#        [[ 95, 372]],
#
#        [[ 95, 373]],
#
#        [[ 94, 374]],
#
#        [[ 93, 373]]], dtype=int32), array([[[ 89, 372]],
#
#        [[ 90, 371]],
#
#        [[ 91, 372]],
#
#        [[ 91, 373]],
#
#        [[ 90, 374]],
#
#        [[ 89, 373]]], dtype=int32), array([[[ 85, 372]],
#
#        [[ 86, 371]],
#
#        [[ 87, 372]],
#
#        [[ 86, 373]]], dtype=int32), array([[[226, 371]],
#
#        [[227, 370]],
#
#        [[228, 371]],
#
#        [[227, 372]]], dtype=int32), array([[[175, 371]],
#
#        [[176, 370]],
#
#        [[177, 370]],
#
#        [[178, 371]],
#
#        [[177, 372]],
#
#        [[176, 372]]], dtype=int32), array([[[171, 371]],
#
#        [[172, 370]],
#
#        [[173, 371]],
#
#        [[172, 372]]], dtype=int32), array([[[116, 371]],
#
#        [[117, 370]],
#
#        [[118, 371]],
#
#        [[118, 372]],
#
#        [[117, 373]],
#
#        [[116, 372]]], dtype=int32), array([[[172, 370]],
#
#        [[173, 369]],
#
#        [[174, 370]],
#
#        [[173, 371]]], dtype=int32), array([[[130, 370]],
#
#        [[131, 369]],
#
#        [[132, 370]],
#
#        [[131, 371]]], dtype=int32), array([[[109, 370]],
#
#        [[110, 369]],
#
#        [[111, 370]],
#
#        [[110, 371]]], dtype=int32), array([[[105, 370]],
#
#        [[106, 369]],
#
#        [[107, 369]],
#
#        [[108, 370]],
#
#        [[107, 371]],
#
#        [[106, 371]]], dtype=int32), array([[[ 90, 370]],
#
#        [[ 91, 369]],
#
#        [[ 92, 370]],
#
#        [[ 92, 371]],
#
#        [[ 91, 372]],
#
#        [[ 90, 371]]], dtype=int32), array([[[ 84, 370]],
#
#        [[ 85, 369]],
#
#        [[ 88, 369]],
#
#        [[ 89, 370]],
#
#        [[ 88, 371]],
#
#        [[ 85, 371]]], dtype=int32), array([[[152, 369]],
#
#        [[153, 368]],
#
#        [[154, 368]],
#
#        [[155, 369]],
#
#        [[154, 370]],
#
#        [[153, 370]]], dtype=int32), array([[[146, 369]],
#
#        [[147, 368]],
#
#        [[148, 368]],
#
#        [[149, 369]],
#
#        [[149, 370]],
#
#        [[148, 371]]], dtype=int32), array([[[103, 369]],
#
#        [[104, 368]],
#
#        [[105, 369]],
#
#        [[104, 370]]], dtype=int32), array([[[ 79, 369]],
#
#        [[ 80, 368]],
#
#        [[ 82, 368]],
#
#        [[ 84, 370]],
#
#        [[ 83, 371]],
#
#        [[ 83, 373]],
#
#        [[ 82, 374]],
#
#        [[ 81, 373]],
#
#        [[ 80, 373]],
#
#        [[ 78, 371]],
#
#        [[ 79, 370]]], dtype=int32), array([[[178, 368]],
#
#        [[179, 367]],
#
#        [[181, 369]],
#
#        [[180, 370]],
#
#        [[179, 370]],
#
#        [[178, 369]]], dtype=int32), array([[[142, 368]],
#
#        [[143, 367]],
#
#        [[146, 367]],
#
#        [[147, 368]],
#
#        [[146, 369]],
#
#        [[143, 369]]], dtype=int32), array([[[139, 368]],
#
#        [[140, 367]],
#
#        [[141, 367]],
#
#        [[142, 368]],
#
#        [[140, 370]],
#
#        [[141, 371]],
#
#        [[141, 372]],
#
#        [[140, 373]],
#
#        [[138, 371]],
#
#        [[138, 370]],
#
#        [[137, 369]],
#
#        [[138, 368]]], dtype=int32), array([[[107, 368]],
#
#        [[108, 367]],
#
#        [[109, 368]],
#
#        [[108, 369]]], dtype=int32), array([[[ 86, 368]],
#
#        [[ 87, 367]],
#
#        [[ 88, 368]],
#
#        [[ 87, 369]]], dtype=int32), array([[[153, 367]],
#
#        [[154, 366]],
#
#        [[160, 366]],
#
#        [[161, 367]],
#
#        [[160, 368]],
#
#        [[158, 368]],
#
#        [[157, 369]],
#
#        [[156, 368]],
#
#        [[154, 368]]], dtype=int32), array([[[136, 366]],
#
#        [[138, 368]],
#
#        [[137, 369]],
#
#        [[137, 370]],
#
#        [[138, 371]],
#
#        [[137, 372]],
#
#        [[135, 372]],
#
#        [[134, 371]],
#
#        [[135, 370]],
#
#        [[135, 369]],
#
#        [[134, 368]]], dtype=int32), array([[[104, 367]],
#
#        [[105, 366]],
#
#        [[106, 367]],
#
#        [[105, 368]]], dtype=int32), array([[[101, 367]],
#
#        [[102, 366]],
#
#        [[103, 367]],
#
#        [[102, 368]]], dtype=int32), array([[[160, 366]],
#
#        [[161, 365]],
#
#        [[162, 366]],
#
#        [[161, 367]]], dtype=int32), array([[[139, 366]],
#
#        [[140, 365]],
#
#        [[141, 366]],
#
#        [[140, 367]]], dtype=int32), array([[[133, 366]],
#
#        [[134, 365]],
#
#        [[135, 366]],
#
#        [[135, 367]],
#
#        [[134, 368]],
#
#        [[134, 371]],
#
#        [[135, 372]],
#
#        [[134, 373]],
#
#        [[133, 373]],
#
#        [[132, 372]],
#
#        [[132, 370]],
#
#        [[130, 368]],
#
#        [[130, 367]],
#
#        [[131, 366]]], dtype=int32), array([[[108, 366]],
#
#        [[109, 365]],
#
#        [[110, 366]],
#
#        [[109, 367]]], dtype=int32), array([[[106, 366]],
#
#        [[107, 365]],
#
#        [[108, 366]],
#
#        [[107, 367]]], dtype=int32), array([[[103, 366]],
#
#        [[104, 365]],
#
#        [[105, 366]],
#
#        [[104, 367]]], dtype=int32), array([[[224, 365]],
#
#        [[225, 364]],
#
#        [[226, 364]],
#
#        [[227, 365]],
#
#        [[227, 366]],
#
#        [[228, 367]],
#
#        [[228, 368]],
#
#        [[227, 369]],
#
#        [[227, 370]],
#
#        [[226, 371]],
#
#        [[225, 370]],
#
#        [[225, 367]],
#
#        [[224, 366]]], dtype=int32), array([[[171, 365]],
#
#        [[172, 364]],
#
#        [[173, 364]],
#
#        [[174, 365]],
#
#        [[173, 366]],
#
#        [[172, 366]]], dtype=int32), array([[[166, 365]],
#
#        [[167, 364]],
#
#        [[169, 364]],
#
#        [[170, 365]],
#
#        [[169, 366]],
#
#        [[167, 366]]], dtype=int32), array([[[164, 365]],
#
#        [[165, 364]],
#
#        [[166, 365]],
#
#        [[165, 366]]], dtype=int32), array([[[162, 365]],
#
#        [[163, 364]],
#
#        [[164, 365]],
#
#        [[163, 366]]], dtype=int32), array([[[147, 365]],
#
#        [[148, 364]],
#
#        [[151, 364]],
#
#        [[152, 365]],
#
#        [[153, 365]],
#
#        [[154, 366]],
#
#        [[153, 367]],
#
#        [[149, 367]]], dtype=int32), array([[[128, 365]],
#
#        [[129, 364]],
#
#        [[130, 365]],
#
#        [[129, 366]]], dtype=int32), array([[[ 77, 365]],
#
#        [[ 78, 364]],
#
#        [[ 79, 365]],
#
#        [[ 78, 366]]], dtype=int32), array([[[181, 364]],
#
#        [[182, 363]],
#
#        [[183, 363]],
#
#        [[184, 364]],
#
#        [[184, 365]],
#
#        [[183, 366]],
#
#        [[183, 367]],
#
#        [[182, 368]],
#
#        [[181, 367]]], dtype=int32), array([[[177, 364]],
#
#        [[178, 363]],
#
#        [[179, 363]],
#
#        [[180, 364]],
#
#        [[180, 366]],
#
#        [[178, 368]],
#
#        [[177, 367]]], dtype=int32), array([[[165, 364]],
#
#        [[166, 363]],
#
#        [[167, 364]],
#
#        [[166, 365]]], dtype=int32), array([[[136, 364]],
#
#        [[137, 363]],
#
#        [[138, 364]],
#
#        [[137, 365]]], dtype=int32), array([[[131, 364]],
#
#        [[132, 363]],
#
#        [[133, 363]],
#
#        [[134, 364]],
#
#        [[133, 365]],
#
#        [[132, 365]]], dtype=int32), array([[[103, 364]],
#
#        [[104, 363]],
#
#        [[105, 364]],
#
#        [[104, 365]]], dtype=int32), array([[[ 97, 364]],
#
#        [[ 98, 363]],
#
#        [[ 99, 364]],
#
#        [[ 99, 365]],
#
#        [[ 98, 366]],
#
#        [[ 97, 365]]], dtype=int32), array([[[ 82, 364]],
#
#        [[ 83, 363]],
#
#        [[ 85, 363]],
#
#        [[ 86, 364]],
#
#        [[ 85, 365]],
#
#        [[ 86, 366]],
#
#        [[ 85, 367]],
#
#        [[ 84, 367]],
#
#        [[ 83, 366]],
#
#        [[ 82, 367]],
#
#        [[ 81, 367]],
#
#        [[ 80, 366]],
#
#        [[ 80, 365]],
#
#        [[ 81, 364]]], dtype=int32), array([[[166, 363]],
#
#        [[167, 362]],
#
#        [[173, 362]],
#
#        [[174, 363]],
#
#        [[173, 364]],
#
#        [[167, 364]]], dtype=int32), array([[[140, 363]],
#
#        [[141, 362]],
#
#        [[142, 363]],
#
#        [[142, 364]],
#
#        [[141, 365]],
#
#        [[140, 364]]], dtype=int32), array([[[118, 363]],
#
#        [[119, 362]],
#
#        [[120, 363]],
#
#        [[119, 364]]], dtype=int32), array([[[224, 362]],
#
#        [[225, 361]],
#
#        [[226, 362]],
#
#        [[226, 363]],
#
#        [[225, 364]],
#
#        [[224, 363]]], dtype=int32), array([[[141, 362]],
#
#        [[142, 361]],
#
#        [[143, 362]],
#
#        [[142, 363]]], dtype=int32), array([[[130, 362]],
#
#        [[131, 361]],
#
#        [[132, 362]],
#
#        [[132, 363]],
#
#        [[131, 364]],
#
#        [[130, 363]]], dtype=int32), array([[[100, 362]],
#
#        [[101, 361]],
#
#        [[102, 362]],
#
#        [[102, 364]],
#
#        [[103, 365]],
#
#        [[102, 366]],
#
#        [[101, 366]],
#
#        [[ 99, 364]],
#
#        [[100, 363]]], dtype=int32), array([[[ 89, 362]],
#
#        [[ 90, 361]],
#
#        [[ 91, 362]],
#
#        [[ 90, 363]]], dtype=int32), array([[[166, 361]],
#
#        [[167, 360]],
#
#        [[168, 361]],
#
#        [[167, 362]]], dtype=int32), array([[[145, 361]],
#
#        [[146, 360]],
#
#        [[147, 361]],
#
#        [[148, 360]],
#
#        [[150, 360]],
#
#        [[152, 362]],
#
#        [[153, 362]],
#
#        [[154, 363]],
#
#        [[159, 363]],
#
#        [[160, 362]],
#
#        [[163, 362]],
#
#        [[164, 363]],
#
#        [[162, 365]],
#
#        [[160, 365]],
#
#        [[159, 366]],
#
#        [[155, 366]],
#
#        [[154, 365]],
#
#        [[153, 365]],
#
#        [[152, 364]],
#
#        [[147, 364]],
#
#        [[146, 365]],
#
#        [[144, 365]],
#
#        [[145, 366]],
#
#        [[144, 367]],
#
#        [[143, 367]],
#
#        [[142, 366]],
#
#        [[142, 364]],
#
#        [[143, 363]],
#
#        [[143, 362]],
#
#        [[144, 361]]], dtype=int32), array([[[142, 361]],
#
#        [[143, 360]],
#
#        [[144, 361]],
#
#        [[143, 362]]], dtype=int32), array([[[ 96, 361]],
#
#        [[ 97, 360]],
#
#        [[ 98, 361]],
#
#        [[ 98, 362]],
#
#        [[ 97, 363]],
#
#        [[ 96, 362]]], dtype=int32), array([[[ 92, 361]],
#
#        [[ 93, 360]],
#
#        [[ 94, 361]],
#
#        [[ 93, 362]]], dtype=int32), array([[[ 77, 361]],
#
#        [[ 78, 360]],
#
#        [[ 79, 360]],
#
#        [[ 80, 361]],
#
#        [[ 80, 362]],
#
#        [[ 79, 363]],
#
#        [[ 78, 363]],
#
#        [[ 77, 362]]], dtype=int32), array([[[363, 360]],
#
#        [[364, 359]],
#
#        [[365, 360]],
#
#        [[365, 362]],
#
#        [[364, 363]],
#
#        [[363, 362]]], dtype=int32), array([[[224, 360]],
#
#        [[225, 359]],
#
#        [[226, 360]],
#
#        [[225, 361]]], dtype=int32), array([[[144, 360]],
#
#        [[145, 359]],
#
#        [[146, 360]],
#
#        [[145, 361]]], dtype=int32), array([[[138, 360]],
#
#        [[139, 359]],
#
#        [[141, 359]],
#
#        [[142, 360]],
#
#        [[140, 362]]], dtype=int32), array([[[101, 360]],
#
#        [[102, 359]],
#
#        [[103, 360]],
#
#        [[102, 361]]], dtype=int32), array([[[ 99, 360]],
#
#        [[100, 359]],
#
#        [[101, 360]],
#
#        [[100, 361]]], dtype=int32), array([[[ 84, 360]],
#
#        [[ 85, 359]],
#
#        [[ 86, 360]],
#
#        [[ 86, 361]],
#
#        [[ 87, 362]],
#
#        [[ 87, 363]],
#
#        [[ 86, 364]],
#
#        [[ 85, 363]],
#
#        [[ 81, 363]],
#
#        [[ 80, 362]],
#
#        [[ 82, 360]]], dtype=int32), array([[[364, 359]],
#
#        [[365, 358]],
#
#        [[366, 359]],
#
#        [[365, 360]]], dtype=int32), array([[[100, 359]],
#
#        [[101, 358]],
#
#        [[102, 359]],
#
#        [[101, 360]]], dtype=int32), array([[[223, 358]],
#
#        [[224, 357]],
#
#        [[225, 358]],
#
#        [[224, 359]]], dtype=int32), array([[[ 86, 358]],
#
#        [[ 87, 357]],
#
#        [[ 88, 358]],
#
#        [[ 87, 359]]], dtype=int32), array([[[364, 357]],
#
#        [[365, 356]],
#
#        [[366, 357]],
#
#        [[365, 358]]], dtype=int32), array([[[101, 357]],
#
#        [[102, 356]],
#
#        [[105, 359]],
#
#        [[104, 360]],
#
#        [[103, 360]],
#
#        [[101, 358]]], dtype=int32), array([[[223, 356]],
#
#        [[224, 355]],
#
#        [[225, 356]],
#
#        [[224, 357]]], dtype=int32), array([[[149, 356]],
#
#        [[150, 355]],
#
#        [[151, 356]],
#
#        [[150, 357]]], dtype=int32), array([[[140, 356]],
#
#        [[141, 355]],
#
#        [[146, 355]],
#
#        [[147, 356]],
#
#        [[146, 357]],
#
#        [[145, 357]],
#
#        [[143, 359]],
#
#        [[141, 359]],
#
#        [[140, 358]],
#
#        [[141, 357]]], dtype=int32), array([[[138, 356]],
#
#        [[139, 355]],
#
#        [[141, 357]],
#
#        [[139, 359]],
#
#        [[137, 359]],
#
#        [[138, 360]],
#
#        [[137, 361]],
#
#        [[135, 361]],
#
#        [[134, 360]],
#
#        [[135, 359]],
#
#        [[135, 357]],
#
#        [[136, 356]],
#
#        [[137, 356]],
#
#        [[138, 357]]], dtype=int32), array([[[108, 356]],
#
#        [[109, 355]],
#
#        [[110, 356]],
#
#        [[109, 357]]], dtype=int32), array([[[119, 355]],
#
#        [[120, 354]],
#
#        [[123, 354]],
#
#        [[124, 355]],
#
#        [[122, 357]],
#
#        [[121, 356]],
#
#        [[120, 356]]], dtype=int32), array([[[116, 355]],
#
#        [[117, 354]],
#
#        [[118, 355]],
#
#        [[118, 356]],
#
#        [[119, 357]],
#
#        [[118, 358]],
#
#        [[117, 358]],
#
#        [[116, 357]]], dtype=int32), array([[[114, 355]],
#
#        [[115, 354]],
#
#        [[116, 355]],
#
#        [[115, 356]]], dtype=int32), array([[[364, 354]],
#
#        [[365, 353]],
#
#        [[366, 354]],
#
#        [[366, 355]],
#
#        [[365, 356]],
#
#        [[364, 355]]], dtype=int32), array([[[362, 354]],
#
#        [[363, 353]],
#
#        [[364, 354]],
#
#        [[364, 358]],
#
#        [[363, 359]],
#
#        [[362, 358]]], dtype=int32), array([[[223, 354]],
#
#        [[224, 353]],
#
#        [[225, 354]],
#
#        [[224, 355]]], dtype=int32), array([[[156, 354]],
#
#        [[157, 353]],
#
#        [[158, 354]],
#
#        [[157, 355]]], dtype=int32), array([[[123, 354]],
#
#        [[124, 353]],
#
#        [[125, 353]],
#
#        [[126, 354]],
#
#        [[125, 355]],
#
#        [[124, 355]]], dtype=int32), array([[[224, 353]],
#
#        [[225, 352]],
#
#        [[226, 353]],
#
#        [[225, 354]]], dtype=int32), array([[[ 98, 353]],
#
#        [[ 99, 352]],
#
#        [[100, 353]],
#
#        [[100, 355]],
#
#        [[ 99, 356]],
#
#        [[ 98, 355]]], dtype=int32), array([[[ 92, 353]],
#
#        [[ 93, 352]],
#
#        [[ 94, 353]],
#
#        [[ 93, 354]]], dtype=int32), array([[[ 86, 353]],
#
#        [[ 87, 352]],
#
#        [[ 89, 352]],
#
#        [[ 90, 353]],
#
#        [[ 89, 354]],
#
#        [[ 87, 354]]], dtype=int32), array([[[365, 352]],
#
#        [[366, 351]],
#
#        [[367, 352]],
#
#        [[366, 353]]], dtype=int32), array([[[153, 352]],
#
#        [[154, 351]],
#
#        [[155, 352]],
#
#        [[154, 353]]], dtype=int32), array([[[128, 352]],
#
#        [[129, 351]],
#
#        [[130, 352]],
#
#        [[129, 353]]], dtype=int32), array([[[112, 351]],
#
#        [[113, 351]],
#
#        [[114, 352]],
#
#        [[113, 353]],
#
#        [[113, 354]],
#
#        [[112, 355]],
#
#        [[111, 355]],
#
#        [[110, 354]],
#
#        [[110, 353]]], dtype=int32), array([[[366, 351]],
#
#        [[367, 350]],
#
#        [[368, 351]],
#
#        [[367, 352]]], dtype=int32), array([[[223, 351]],
#
#        [[224, 350]],
#
#        [[225, 351]],
#
#        [[224, 352]]], dtype=int32), array([[[136, 351]],
#
#        [[137, 350]],
#
#        [[142, 350]],
#
#        [[143, 351]],
#
#        [[142, 352]],
#
#        [[137, 352]]], dtype=int32), array([[[133, 351]],
#
#        [[134, 350]],
#
#        [[135, 351]],
#
#        [[134, 352]]], dtype=int32), array([[[125, 351]],
#
#        [[126, 350]],
#
#        [[127, 351]],
#
#        [[126, 352]]], dtype=int32), array([[[109, 351]],
#
#        [[110, 350]],
#
#        [[111, 350]],
#
#        [[112, 351]],
#
#        [[111, 352]],
#
#        [[110, 352]]], dtype=int32), array([[[ 99, 351]],
#
#        [[100, 350]],
#
#        [[102, 352]],
#
#        [[101, 353]],
#
#        [[100, 353]],
#
#        [[ 99, 352]]], dtype=int32), array([[[ 91, 351]],
#
#        [[ 92, 350]],
#
#        [[ 93, 351]],
#
#        [[ 92, 352]]], dtype=int32), array([[[132, 350]],
#
#        [[133, 349]],
#
#        [[134, 350]],
#
#        [[133, 351]]], dtype=int32), array([[[ 98, 349]],
#
#        [[ 99, 350]],
#
#        [[ 99, 352]],
#
#        [[ 98, 353]],
#
#        [[ 96, 353]],
#
#        [[ 95, 352]]], dtype=int32), array([[[ 88, 350]],
#
#        [[ 89, 349]],
#
#        [[ 90, 350]],
#
#        [[ 89, 351]]], dtype=int32), array([[[361, 349]],
#
#        [[362, 348]],
#
#        [[363, 348]],
#
#        [[364, 349]],
#
#        [[363, 350]],
#
#        [[364, 350]],
#
#        [[365, 351]],
#
#        [[364, 352]],
#
#        [[363, 352]],
#
#        [[363, 353]],
#
#        [[362, 354]],
#
#        [[361, 353]]], dtype=int32), array([[[126, 349]],
#
#        [[127, 348]],
#
#        [[128, 349]],
#
#        [[128, 350]],
#
#        [[127, 351]],
#
#        [[126, 350]]], dtype=int32), array([[[ 98, 349]],
#
#        [[ 99, 348]],
#
#        [[100, 349]],
#
#        [[ 99, 350]]], dtype=int32), array([[[ 93, 348]],
#
#        [[ 94, 347]],
#
#        [[ 95, 348]],
#
#        [[ 95, 349]],
#
#        [[ 94, 350]],
#
#        [[ 93, 349]]], dtype=int32), array([[[ 90, 348]],
#
#        [[ 91, 347]],
#
#        [[ 92, 348]],
#
#        [[ 92, 349]],
#
#        [[ 91, 350]],
#
#        [[ 90, 349]]], dtype=int32), array([[[ 88, 348]],
#
#        [[ 89, 347]],
#
#        [[ 90, 348]],
#
#        [[ 89, 349]]], dtype=int32), array([[[223, 347]],
#
#        [[224, 346]],
#
#        [[225, 347]],
#
#        [[224, 348]]], dtype=int32), array([[[108, 347]],
#
#        [[109, 346]],
#
#        [[110, 346]],
#
#        [[112, 348]],
#
#        [[111, 349]],
#
#        [[110, 349]]], dtype=int32), array([[[ 94, 347]],
#
#        [[ 95, 346]],
#
#        [[ 96, 346]],
#
#        [[ 97, 347]],
#
#        [[ 96, 348]],
#
#        [[ 95, 348]]], dtype=int32), array([[[ 89, 347]],
#
#        [[ 90, 346]],
#
#        [[ 91, 347]],
#
#        [[ 90, 348]]], dtype=int32), array([[[ 77, 347]],
#
#        [[ 78, 346]],
#
#        [[ 79, 346]],
#
#        [[ 80, 347]],
#
#        [[ 80, 349]],
#
#        [[ 79, 350]],
#
#        [[ 78, 350]],
#
#        [[ 77, 349]]], dtype=int32), array([[[110, 346]],
#
#        [[111, 345]],
#
#        [[112, 346]],
#
#        [[111, 347]]], dtype=int32), array([[[ 83, 346]],
#
#        [[ 84, 345]],
#
#        [[ 85, 345]],
#
#        [[ 86, 346]],
#
#        [[ 85, 347]],
#
#        [[ 84, 347]]], dtype=int32), array([[[ 94, 345]],
#
#        [[ 95, 344]],
#
#        [[ 96, 345]],
#
#        [[ 95, 346]]], dtype=int32), array([[[ 87, 345]],
#
#        [[ 88, 344]],
#
#        [[ 89, 344]],
#
#        [[ 90, 345]],
#
#        [[ 88, 347]],
#
#        [[ 87, 346]]], dtype=int32), array([[[ 85, 345]],
#
#        [[ 86, 344]],
#
#        [[ 87, 345]],
#
#        [[ 86, 346]]], dtype=int32), array([[[ 82, 345]],
#
#        [[ 83, 344]],
#
#        [[ 84, 345]],
#
#        [[ 83, 346]]], dtype=int32), array([[[ 86, 344]],
#
#        [[ 87, 343]],
#
#        [[ 88, 344]],
#
#        [[ 87, 345]]], dtype=int32), array([[[ 97, 343]],
#
#        [[ 98, 342]],
#
#        [[ 99, 343]],
#
#        [[ 98, 344]]], dtype=int32), array([[[ 89, 343]],
#
#        [[ 90, 342]],
#
#        [[ 91, 343]],
#
#        [[ 90, 344]]], dtype=int32), array([[[223, 342]],
#
#        [[224, 341]],
#
#        [[225, 342]],
#
#        [[224, 343]]], dtype=int32), array([[[ 94, 342]],
#
#        [[ 95, 341]],
#
#        [[ 96, 342]],
#
#        [[ 95, 343]]], dtype=int32), array([[[ 91, 342]],
#
#        [[ 92, 341]],
#
#        [[ 93, 342]],
#
#        [[ 94, 342]],
#
#        [[ 95, 343]],
#
#        [[ 95, 344]],
#
#        [[ 94, 345]],
#
#        [[ 93, 344]],
#
#        [[ 92, 344]],
#
#        [[ 91, 343]]], dtype=int32), array([[[ 88, 342]],
#
#        [[ 89, 341]],
#
#        [[ 90, 342]],
#
#        [[ 89, 343]]], dtype=int32), array([[[ 96, 341]],
#
#        [[ 97, 340]],
#
#        [[ 98, 341]],
#
#        [[ 97, 342]]], dtype=int32), array([[[ 90, 341]],
#
#        [[ 91, 340]],
#
#        [[ 92, 341]],
#
#        [[ 91, 342]]], dtype=int32), array([[[ 91, 339]],
#
#        [[ 92, 338]],
#
#        [[ 93, 339]],
#
#        [[ 93, 340]],
#
#        [[ 92, 341]],
#
#        [[ 91, 340]]], dtype=int32), array([[[ 97, 338]],
#
#        [[ 98, 337]],
#
#        [[ 99, 338]],
#
#        [[ 98, 339]]], dtype=int32), array([[[ 87, 338]],
#
#        [[ 88, 337]],
#
#        [[ 89, 338]],
#
#        [[ 90, 338]],
#
#        [[ 91, 339]],
#
#        [[ 90, 340]],
#
#        [[ 88, 340]],
#
#        [[ 87, 339]]], dtype=int32), array([[[ 92, 337]],
#
#        [[ 93, 336]],
#
#        [[ 94, 337]],
#
#        [[ 94, 338]],
#
#        [[ 93, 339]],
#
#        [[ 92, 338]]], dtype=int32), array([[[ 88, 337]],
#
#        [[ 89, 336]],
#
#        [[ 90, 337]],
#
#        [[ 89, 338]]], dtype=int32), array([[[357, 336]],
#
#        [[358, 335]],
#
#        [[359, 336]],
#
#        [[359, 337]],
#
#        [[358, 338]],
#
#        [[357, 337]]], dtype=int32), array([[[ 93, 335]],
#
#        [[ 94, 334]],
#
#        [[ 95, 335]],
#
#        [[ 94, 336]]], dtype=int32), array([[[367, 334]],
#
#        [[368, 333]],
#
#        [[369, 334]],
#
#        [[369, 336]],
#
#        [[370, 337]],
#
#        [[370, 340]],
#
#        [[371, 341]],
#
#        [[371, 345]],
#
#        [[372, 346]],
#
#        [[372, 367]],
#
#        [[371, 368]],
#
#        [[371, 372]],
#
#        [[370, 373]],
#
#        [[370, 376]],
#
#        [[369, 377]],
#
#        [[369, 379]],
#
#        [[368, 380]],
#
#        [[368, 382]],
#
#        [[367, 383]],
#
#        [[367, 384]],
#
#        [[366, 385]],
#
#        [[366, 387]],
#
#        [[365, 388]],
#
#        [[365, 389]],
#
#        [[364, 390]],
#
#        [[364, 391]],
#
#        [[363, 392]],
#
#        [[363, 393]],
#
#        [[361, 395]],
#
#        [[361, 396]],
#
#        [[359, 398]],
#
#        [[359, 399]],
#
#        [[356, 402]],
#
#        [[356, 403]],
#
#        [[345, 414]],
#
#        [[344, 414]],
#
#        [[341, 417]],
#
#        [[340, 417]],
#
#        [[338, 419]],
#
#        [[337, 419]],
#
#        [[336, 420]],
#
#        [[335, 420]],
#
#        [[333, 422]],
#
#        [[332, 422]],
#
#        [[331, 423]],
#
#        [[330, 423]],
#
#        [[329, 424]],
#
#        [[328, 424]],
#
#        [[327, 425]],
#
#        [[325, 425]],
#
#        [[324, 426]],
#
#        [[322, 426]],
#
#        [[321, 427]],
#
#        [[319, 427]],
#
#        [[318, 428]],
#
#        [[315, 428]],
#
#        [[314, 429]],
#
#        [[310, 429]],
#
#        [[309, 430]],
#
#        [[288, 430]],
#
#        [[287, 429]],
#
#        [[282, 429]],
#
#        [[281, 428]],
#
#        [[278, 428]],
#
#        [[277, 427]],
#
#        [[275, 427]],
#
#        [[274, 426]],
#
#        [[272, 426]],
#
#        [[271, 425]],
#
#        [[270, 425]],
#
#        [[269, 424]],
#
#        [[268, 424]],
#
#        [[267, 423]],
#
#        [[265, 423]],
#
#        [[263, 421]],
#
#        [[262, 421]],
#
#        [[261, 420]],
#
#        [[260, 420]],
#
#        [[258, 418]],
#
#        [[257, 418]],
#
#        [[255, 416]],
#
#        [[254, 416]],
#
#        [[250, 412]],
#
#        [[249, 412]],
#
#        [[246, 409]],
#
#        [[246, 408]],
#
#        [[247, 407]],
#
#        [[249, 409]],
#
#        [[250, 409]],
#
#        [[252, 411]],
#
#        [[253, 411]],
#
#        [[255, 413]],
#
#        [[256, 413]],
#
#        [[258, 415]],
#
#        [[259, 415]],
#
#        [[260, 416]],
#
#        [[261, 416]],
#
#        [[263, 418]],
#
#        [[264, 418]],
#
#        [[265, 419]],
#
#        [[266, 419]],
#
#        [[267, 420]],
#
#        [[268, 419]],
#
#        [[269, 420]],
#
#        [[270, 419]],
#
#        [[271, 420]],
#
#        [[271, 421]],
#
#        [[273, 421]],
#
#        [[274, 422]],
#
#        [[277, 422]],
#
#        [[278, 423]],
#
#        [[281, 423]],
#
#        [[282, 424]],
#
#        [[283, 424]],
#
#        [[284, 423]],
#
#        [[285, 423]],
#
#        [[286, 424]],
#
#        [[286, 425]],
#
#        [[287, 425]],
#
#        [[288, 424]],
#
#        [[289, 424]],
#
#        [[290, 425]],
#
#        [[291, 425]],
#
#        [[292, 424]],
#
#        [[293, 424]],
#
#        [[294, 425]],
#
#        [[295, 425]],
#
#        [[296, 424]],
#
#        [[297, 425]],
#
#        [[307, 425]],
#
#        [[308, 424]],
#
#        [[312, 424]],
#
#        [[313, 423]],
#
#        [[316, 423]],
#
#        [[317, 422]],
#
#        [[319, 422]],
#
#        [[320, 421]],
#
#        [[321, 421]],
#
#        [[322, 420]],
#
#        [[324, 420]],
#
#        [[325, 419]],
#
#        [[326, 419]],
#
#        [[327, 418]],
#
#        [[328, 418]],
#
#        [[329, 417]],
#
#        [[330, 417]],
#
#        [[331, 416]],
#
#        [[332, 416]],
#
#        [[334, 414]],
#
#        [[335, 414]],
#
#        [[336, 413]],
#
#        [[337, 413]],
#
#        [[340, 410]],
#
#        [[341, 410]],
#
#        [[345, 406]],
#
#        [[346, 406]],
#
#        [[346, 405]],
#
#        [[347, 404]],
#
#        [[348, 404]],
#
#        [[349, 403]],
#
#        [[349, 402]],
#
#        [[354, 397]],
#
#        [[354, 396]],
#
#        [[356, 394]],
#
#        [[356, 393]],
#
#        [[358, 391]],
#
#        [[358, 390]],
#
#        [[359, 389]],
#
#        [[359, 388]],
#
#        [[361, 386]],
#
#        [[361, 385]],
#
#        [[362, 384]],
#
#        [[362, 382]],
#
#        [[363, 381]],
#
#        [[363, 380]],
#
#        [[364, 379]],
#
#        [[364, 377]],
#
#        [[365, 376]],
#
#        [[365, 374]],
#
#        [[366, 373]],
#
#        [[366, 370]],
#
#        [[367, 369]],
#
#        [[367, 365]],
#
#        [[368, 364]],
#
#        [[368, 358]],
#
#        [[369, 357]],
#
#        [[369, 345]],
#
#        [[368, 344]],
#
#        [[368, 338]],
#
#        [[367, 337]]], dtype=int32), array([[[ 97, 334]],
#
#        [[ 98, 333]],
#
#        [[ 99, 334]],
#
#        [[ 98, 335]]], dtype=int32), array([[[ 94, 334]],
#
#        [[ 95, 333]],
#
#        [[ 96, 334]],
#
#        [[ 95, 335]]], dtype=int32), array([[[ 80, 334]],
#
#        [[ 81, 333]],
#
#        [[ 83, 333]],
#
#        [[ 84, 334]],
#
#        [[ 84, 335]],
#
#        [[ 85, 334]],
#
#        [[ 86, 334]],
#
#        [[ 87, 335]],
#
#        [[ 87, 337]],
#
#        [[ 86, 338]],
#
#        [[ 85, 338]],
#
#        [[ 84, 337]],
#
#        [[ 83, 337]],
#
#        [[ 82, 336]],
#
#        [[ 81, 336]],
#
#        [[ 80, 335]]], dtype=int32), array([[[358, 333]],
#
#        [[359, 332]],
#
#        [[360, 333]],
#
#        [[359, 334]]], dtype=int32), array([[[354, 333]],
#
#        [[355, 332]],
#
#        [[357, 334]],
#
#        [[355, 336]],
#
#        [[354, 335]]], dtype=int32), array([[[228, 333]],
#
#        [[229, 332]],
#
#        [[230, 333]],
#
#        [[230, 334]],
#
#        [[229, 335]],
#
#        [[228, 334]]], dtype=int32), array([[[225, 333]],
#
#        [[226, 332]],
#
#        [[227, 333]],
#
#        [[227, 335]],
#
#        [[228, 334]],
#
#        [[229, 335]],
#
#        [[229, 336]],
#
#        [[227, 338]],
#
#        [[227, 339]],
#
#        [[225, 341]],
#
#        [[224, 340]],
#
#        [[224, 339]],
#
#        [[225, 338]]], dtype=int32), array([[[ 98, 333]],
#
#        [[ 99, 332]],
#
#        [[100, 333]],
#
#        [[ 99, 334]]], dtype=int32), array([[[511, 332]],
#
#        [[512, 331]],
#
#        [[513, 332]],
#
#        [[513, 333]],
#
#        [[514, 334]],
#
#        [[514, 337]],
#
#        [[513, 338]],
#
#        [[512, 337]],
#
#        [[512, 335]],
#
#        [[511, 334]]], dtype=int32), array([[[ 90, 332]],
#
#        [[ 91, 331]],
#
#        [[ 92, 332]],
#
#        [[ 92, 334]],
#
#        [[ 93, 335]],
#
#        [[ 92, 336]],
#
#        [[ 91, 336]],
#
#        [[ 90, 335]]], dtype=int32), array([[[366, 331]],
#
#        [[367, 330]],
#
#        [[368, 331]],
#
#        [[368, 332]],
#
#        [[367, 333]],
#
# ...
#        [[432,  64]],
#
#        [[431,  65]],
#
#        [[429,  65]],
#
#        [[429,  66]],
#
#        [[427,  68]],
#
#        [[427,  69]],
#
#        [[426,  70]],
#
#        [[423,  70]],
#
#        [[422,  71]],
#
#        [[421,  71]],
#
#        [[421,  72]],
#
#        [[422,  71]],
#
#        [[425,  71]],
#
#        [[427,  69]],
#
#        [[427,  68]],
#
#        [[430,  65]],
#
#        [[431,  66]],
#
#        [[432,  65]],
#
#        [[434,  65]],
#
#        [[436,  67]],
#
#        [[437,  67]],
#
#        [[438,  66]],
#
#        [[435,  66]],
#
#        [[434,  65]],
#
#        [[434,  63]],
#
#        [[433,  62]]], dtype=int32), array([[[431,  63]],
#
#        [[432,  62]],
#
#        [[433,  63]],
#
#        [[432,  64]]], dtype=int32), array([[[441,  61]]], dtype=int32), array([[[435,  61]],
#
#        [[436,  61]]], dtype=int32), array([[[439,  60]]], dtype=int32), array([[[411,  60]],
#
#        [[412,  60]],
#
#        [[413,  61]],
#
#        [[413,  62]],
#
#        [[412,  63]],
#
#        [[411,  62]],
#
#        [[410,  62]],
#
#        [[411,  62]],
#
#        [[412,  63]],
#
#        [[413,  62]],
#
#        [[413,  61]],
#
#        [[412,  60]]], dtype=int32), array([[[409,  60]]], dtype=int32), array([[[467,  58]],
#
#        [[468,  58]]], dtype=int32), array([[[434,  58]],
#
#        [[435,  59]],
#
#        [[437,  59]],
#
#        [[436,  59]],
#
#        [[435,  58]]], dtype=int32), array([[[410,  58]]], dtype=int32), array([[[471,  57]],
#
#        [[470,  58]],
#
#        [[470,  59]],
#
#        [[469,  60]],
#
#        [[468,  60]],
#
#        [[469,  61]],
#
#        [[469,  60]],
#
#        [[472,  57]]], dtype=int32), array([[[437,  57]]], dtype=int32), array([[[466,  56]]], dtype=int32), array([[[433,  56]],
#
#        [[434,  56]]], dtype=int32), array([[[430,  56]]], dtype=int32), array([[[428,  56]],
#
#        [[427,  57]],
#
#        [[426,  57]],
#
#        [[423,  60]],
#
#        [[425,  58]],
#
#        [[426,  58]],
#
#        [[427,  57]],
#
#        [[428,  57]],
#
#        [[429,  58]],
#
#        [[425,  62]],
#
#        [[424,  62]],
#
#        [[425,  62]],
#
#        [[426,  61]],
#
#        [[427,  61]],
#
#        [[428,  60]],
#
#        [[428,  59]],
#
#        [[429,  58]],
#
#        [[428,  57]]], dtype=int32), array([[[437,  55]],
#
#        [[438,  55]]], dtype=int32), array([[[414,  55]],
#
#        [[415,  56]],
#
#        [[415,  57]],
#
#        [[414,  58]],
#
#        [[412,  58]],
#
#        [[413,  58]],
#
#        [[414,  59]],
#
#        [[415,  58]],
#
#        [[416,  59]],
#
#        [[416,  60]],
#
#        [[418,  58]],
#
#        [[418,  57]],
#
#        [[418,  58]],
#
#        [[417,  59]],
#
#        [[416,  59]],
#
#        [[415,  58]],
#
#        [[416,  57]],
#
#        [[416,  56]],
#
#        [[417,  55]],
#
#        [[416,  56]],
#
#        [[415,  56]]], dtype=int32), array([[[467,  54]],
#
#        [[468,  54]]], dtype=int32), array([[[430,  54]]], dtype=int32), array([[[432,  53]],
#
#        [[432,  54]],
#
#        [[435,  54]],
#
#        [[436,  53]],
#
#        [[435,  53]],
#
#        [[434,  54]],
#
#        [[433,  54]]], dtype=int32), array([[[413,  53]]], dtype=int32), array([[[466,  52]],
#
#        [[464,  54]],
#
#        [[465,  54]],
#
#        [[465,  53]],
#
#        [[466,  52]],
#
#        [[467,  52]]], dtype=int32), array([[[437,  51]]], dtype=int32), array([[[434,  51]],
#
#        [[435,  51]]], dtype=int32), array([[[432,  51]]], dtype=int32), array([[[418,  51]],
#
#        [[417,  52]],
#
#        [[419,  54]],
#
#        [[418,  53]],
#
#        [[419,  52]],
#
#        [[420,  52]],
#
#        [[419,  51]]], dtype=int32), array([[[417,  52]],
#
#        [[418,  51]],
#
#        [[419,  52]],
#
#        [[418,  53]]], dtype=int32), array([[[430,  50]],
#
#        [[430,  51]]], dtype=int32), array([[[462,  48]],
#
#        [[461,  49]],
#
#        [[461,  50]],
#
#        [[460,  51]],
#
#        [[461,  52]],
#
#        [[462,  52]],
#
#        [[464,  50]],
#
#        [[462,  52]],
#
#        [[461,  52]],
#
#        [[460,  51]],
#
#        [[463,  48]]], dtype=int32), array([[[454,  47]],
#
#        [[455,  48]]], dtype=int32), array([[[458,  46]],
#
#        [[458,  47]],
#
#        [[457,  48]],
#
#        [[457,  49]],
#
#        [[457,  48]],
#
#        [[458,  47]],
#
#        [[459,  48]],
#
#        [[460,  47]],
#
#        [[459,  48]],
#
#        [[458,  47]]], dtype=int32), array([[[450,  44]],
#
#        [[450,  45]],
#
#        [[451,  46]],
#
#        [[452,  46]],
#
#        [[453,  45]],
#
#        [[453,  44]],
#
#        [[451,  46]],
#
#        [[450,  45]]], dtype=int32), array([[[439,  44]],
#
#        [[439,  45]]], dtype=int32), array([[[450,  42]]], dtype=int32), array([[[448,  42]],
#
#        [[446,  44]],
#
#        [[447,  45]],
#
#        [[446,  44]]], dtype=int32), array([[[444,  41]],
#
#        [[443,  42]],
#
#        [[442,  42]],
#
#        [[444,  44]],
#
#        [[443,  43]],
#
#        [[443,  42]]], dtype=int32), array([[[438,  41]],
#
#        [[439,  41]]], dtype=int32), array([[[435,  41]],
#
#        [[434,  42]],
#
#        [[433,  42]],
#
#        [[434,  43]],
#
#        [[435,  43]],
#
#        [[436,  44]],
#
#        [[435,  45]],
#
#        [[434,  45]],
#
#        [[436,  45]],
#
#        [[436,  44]],
#
#        [[435,  43]],
#
#        [[436,  42]]], dtype=int32), array([[[434,  42]],
#
#        [[435,  41]],
#
#        [[436,  42]],
#
#        [[435,  43]]], dtype=int32), array([[[447,  40]],
#
#        [[446,  41]]], dtype=int32), array([[[441,  40]]], dtype=int32), array([[[425,  39]],
#
#        [[426,  38]],
#
#        [[427,  38]],
#
#        [[428,  39]],
#
#        [[427,  40]],
#
#        [[426,  40]]], dtype=int32), array([[[324,  39]],
#
#        [[325,  38]],
#
#        [[328,  41]],
#
#        [[327,  42]],
#
#        [[326,  42]],
#
#        [[324,  40]]], dtype=int32), array([[[266,  39]],
#
#        [[267,  38]],
#
#        [[268,  39]],
#
#        [[267,  40]]], dtype=int32), array([[[259,  39]],
#
#        [[260,  38]],
#
#        [[261,  38]],
#
#        [[262,  39]],
#
#        [[261,  40]],
#
#        [[260,  40]]], dtype=int32), array([[[141,  39]],
#
#        [[142,  38]],
#
#        [[143,  39]],
#
#        [[142,  40]]], dtype=int32), array([[[138,  39]],
#
#        [[139,  38]],
#
#        [[140,  39]],
#
#        [[139,  40]]], dtype=int32), array([[[135,  39]],
#
#        [[136,  38]],
#
#        [[137,  39]],
#
#        [[136,  40]]], dtype=int32), array([[[126,  39]],
#
#        [[127,  38]],
#
#        [[128,  38]],
#
#        [[129,  39]],
#
#        [[128,  40]],
#
#        [[127,  40]]], dtype=int32), array([[[124,  39]],
#
#        [[125,  38]],
#
#        [[126,  39]],
#
#        [[125,  40]]], dtype=int32), array([[[109,  39]],
#
#        [[110,  38]],
#
#        [[111,  39]],
#
#        [[110,  40]]], dtype=int32), array([[[427,  38]],
#
#        [[428,  37]],
#
#        [[430,  37]],
#
#        [[431,  38]],
#
#        [[430,  39]],
#
#        [[428,  39]]], dtype=int32), array([[[317,  38]],
#
#        [[318,  37]],
#
#        [[319,  38]],
#
#        [[318,  39]]], dtype=int32), array([[[285,  38]],
#
#        [[286,  37]],
#
#        [[289,  37]],
#
#        [[290,  38]],
#
#        [[289,  39]],
#
#        [[286,  39]]], dtype=int32), array([[[267,  38]],
#
#        [[268,  37]],
#
#        [[271,  37]],
#
#        [[272,  38]],
#
#        [[271,  39]],
#
#        [[268,  39]]], dtype=int32), array([[[262,  38]],
#
#        [[263,  37]],
#
#        [[264,  38]],
#
#        [[263,  39]]], dtype=int32), array([[[238,  38]],
#
#        [[239,  37]],
#
#        [[240,  38]],
#
#        [[239,  39]]], dtype=int32), array([[[132,  38]],
#
#        [[133,  37]],
#
#        [[134,  38]],
#
#        [[133,  39]]], dtype=int32), array([[[129,  38]],
#
#        [[130,  37]],
#
#        [[131,  37]],
#
#        [[132,  38]],
#
#        [[131,  39]],
#
#        [[130,  39]]], dtype=int32), array([[[110,  38]],
#
#        [[111,  37]],
#
#        [[112,  37]],
#
#        [[113,  38]],
#
#        [[112,  39]],
#
#        [[111,  39]]], dtype=int32), array([[[323,  37]],
#
#        [[324,  36]],
#
#        [[325,  37]],
#
#        [[325,  38]],
#
#        [[324,  39]],
#
#        [[323,  38]]], dtype=int32), array([[[314,  37]],
#
#        [[315,  36]],
#
#        [[317,  36]],
#
#        [[318,  37]],
#
#        [[317,  38]],
#
#        [[315,  38]]], dtype=int32), array([[[295,  37]],
#
#        [[296,  36]],
#
#        [[297,  37]],
#
#        [[296,  38]]], dtype=int32), array([[[272,  37]],
#
#        [[273,  36]],
#
#        [[274,  37]],
#
#        [[273,  38]]], dtype=int32), array([[[252,  37]],
#
#        [[253,  36]],
#
#        [[254,  37]],
#
#        [[253,  38]]], dtype=int32), array([[[239,  37]],
#
#        [[240,  36]],
#
#        [[241,  37]],
#
#        [[240,  38]]], dtype=int32), array([[[113,  37]],
#
#        [[114,  36]],
#
#        [[115,  37]],
#
#        [[114,  38]]], dtype=int32), array([[[435,  36]],
#
#        [[436,  35]],
#
#        [[448,  35]],
#
#        [[449,  36]],
#
#        [[453,  36]],
#
#        [[454,  37]],
#
#        [[456,  37]],
#
#        [[457,  38]],
#
#        [[458,  38]],
#
#        [[459,  39]],
#
#        [[460,  39]],
#
#        [[461,  40]],
#
#        [[462,  40]],
#
#        [[463,  41]],
#
#        [[464,  41]],
#
#        [[466,  43]],
#
#        [[467,  43]],
#
#        [[473,  49]],
#
#        [[472,  50]],
#
#        [[470,  50]],
#
#        [[465,  45]],
#
#        [[464,  45]],
#
#        [[462,  43]],
#
#        [[461,  43]],
#
#        [[460,  42]],
#
#        [[459,  42]],
#
#        [[458,  41]],
#
#        [[457,  41]],
#
#        [[455,  39]],
#
#        [[452,  39]],
#
#        [[451,  38]],
#
#        [[446,  38]],
#
#        [[445,  37]],
#
#        [[444,  37]],
#
#        [[443,  38]],
#
#        [[442,  37]],
#
#        [[437,  37]],
#
#        [[436,  38]],
#
#        [[432,  38]],
#
#        [[431,  37]],
#
#        [[432,  36]]], dtype=int32), array([[[313,  36]],
#
#        [[314,  35]],
#
#        [[315,  36]],
#
#        [[314,  37]]], dtype=int32), array([[[240,  36]],
#
#        [[241,  35]],
#
#        [[242,  36]],
#
#        [[241,  37]]], dtype=int32), array([[[115,  36]],
#
#        [[116,  35]],
#
#        [[117,  35]],
#
#        [[118,  36]],
#
#        [[116,  38]],
#
#        [[115,  37]]], dtype=int32), array([[[312,  35]],
#
#        [[313,  34]],
#
#        [[314,  35]],
#
#        [[313,  36]]], dtype=int32), array([[[288,  35]],
#
#        [[289,  34]],
#
#        [[290,  35]],
#
#        [[290,  36]],
#
#        [[289,  37]],
#
#        [[288,  36]]], dtype=int32), array([[[117,  35]],
#
#        [[118,  34]],
#
#        [[119,  34]],
#
#        [[120,  35]],
#
#        [[119,  36]],
#
#        [[118,  36]]], dtype=int32), array([[[317,  34]],
#
#        [[318,  33]],
#
#        [[319,  33]],
#
#        [[320,  34]],
#
#        [[321,  34]],
#
#        [[322,  35]],
#
#        [[323,  35]],
#
#        [[324,  36]],
#
#        [[323,  37]],
#
#        [[321,  37]],
#
#        [[320,  36]],
#
#        [[319,  36]]], dtype=int32), array([[[264,  34]],
#
#        [[265,  33]],
#
#        [[268,  33]],
#
#        [[269,  34]],
#
#        [[268,  35]],
#
#        [[267,  35]],
#
#        [[266,  36]],
#
#        [[263,  36]],
#
#        [[262,  35]],
#
#        [[263,  34]]], dtype=int32), array([[[293,  33]],
#
#        [[294,  32]],
#
#        [[295,  32]],
#
#        [[296,  33]],
#
#        [[296,  34]],
#
#        [[295,  35]]], dtype=int32), array([[[268,  33]],
#
#        [[269,  32]],
#
#        [[270,  33]],
#
#        [[269,  34]]], dtype=int32), array([[[257,  33]],
#
#        [[258,  32]],
#
#        [[259,  33]],
#
#        [[258,  34]]], dtype=int32), array([[[242,  33]],
#
#        [[243,  32]],
#
#        [[244,  33]],
#
#        [[244,  34]],
#
#        [[243,  35]],
#
#        [[242,  34]]], dtype=int32), array([[[316,  32]],
#
#        [[317,  31]],
#
#        [[318,  32]],
#
#        [[317,  33]]], dtype=int32), array([[[289,  32]],
#
#        [[290,  31]],
#
#        [[293,  31]],
#
#        [[294,  32]],
#
#        [[293,  33]],
#
#        [[290,  33]]], dtype=int32), array([[[269,  32]],
#
#        [[270,  31]],
#
#        [[271,  32]],
#
#        [[270,  33]]], dtype=int32), array([[[258,  32]],
#
#        [[259,  31]],
#
#        [[260,  32]],
#
#        [[259,  33]]], dtype=int32), array([[[243,  32]],
#
#        [[244,  31]],
#
#        [[245,  32]],
#
#        [[244,  33]]], dtype=int32), array([[[131,  32]],
#
#        [[132,  31]],
#
#        [[136,  31]],
#
#        [[137,  32]],
#
#        [[143,  32]],
#
#        [[144,  33]],
#
#        [[147,  33]],
#
#        [[148,  34]],
#
#        [[150,  34]],
#
#        [[151,  35]],
#
#        [[153,  35]],
#
#        [[154,  36]],
#
#        [[155,  36]],
#
#        [[156,  37]],
#
#        [[157,  37]],
#
#        [[158,  38]],
#
#        [[159,  38]],
#
#        [[161,  40]],
#
#        [[162,  40]],
#
#        [[170,  48]],
#
#        [[168,  50]],
#
#        [[160,  42]],
#
#        [[159,  42]],
#
#        [[158,  41]],
#
#        [[157,  41]],
#
#        [[156,  40]],
#
#        [[155,  40]],
#
#        [[153,  38]],
#
#        [[151,  38]],
#
#        [[150,  37]],
#
#        [[148,  37]],
#
#        [[147,  36]],
#
#        [[146,  36]],
#
#        [[145,  35]],
#
#        [[142,  35]],
#
#        [[141,  36]],
#
#        [[140,  36]],
#
#        [[139,  35]],
#
#        [[139,  34]],
#
#        [[137,  34]],
#
#        [[136,  35]],
#
#        [[135,  34]],
#
#        [[134,  34]],
#
#        [[133,  35]],
#
#        [[131,  35]],
#
#        [[130,  34]],
#
#        [[127,  34]],
#
#        [[125,  36]],
#
#        [[124,  36]],
#
#        [[123,  35]],
#
#        [[121,  35]],
#
#        [[120,  34]],
#
#        [[121,  33]],
#
#        [[124,  33]],
#
#        [[125,  32]]], dtype=int32), array([[[262,  31]],
#
#        [[263,  30]],
#
#        [[264,  30]],
#
#        [[265,  31]],
#
#        [[263,  33]],
#
#        [[261,  33]],
#
#        [[260,  32]],
#
#        [[261,  31]]], dtype=int32), array([[[244,  31]],
#
#        [[245,  30]],
#
#        [[246,  31]],
#
#        [[245,  32]]], dtype=int32), array([[[264,  30]],
#
#        [[265,  29]],
#
#        [[266,  30]],
#
#        [[265,  31]]], dtype=int32), array([[[245,  30]],
#
#        [[246,  29]],
#
#        [[247,  30]],
#
#        [[246,  31]]], dtype=int32), array([[[265,  29]],
#
#        [[266,  28]],
#
#        [[267,  29]],
#
#        [[266,  30]]], dtype=int32), array([[[246,  29]],
#
#        [[247,  28]],
#
#        [[248,  29]],
#
#        [[247,  30]]], dtype=int32), array([[[296,  28]],
#
#        [[297,  27]],
#
#        [[298,  28]],
#
#        [[297,  29]]], dtype=int32), array([[[266,  28]],
#
#        [[267,  27]],
#
#        [[268,  28]],
#
#        [[267,  29]]], dtype=int32), array([[[247,  28]],
#
#        [[248,  27]],
#
#        [[249,  28]],
#
#        [[248,  29]]], dtype=int32), array([[[250,  25]],
#
#        [[251,  26]],
#
#        [[251,  27]],
#
#        [[250,  28]],
#
#        [[249,  28]],
#
#        [[248,  27]]], dtype=int32), array([[[287,  25]],
#
#        [[288,  24]],
#
#        [[289,  25]],
#
#        [[297,  25]],
#
#        [[298,  26]],
#
#        [[297,  27]],
#
#        [[288,  27]],
#
#        [[287,  26]]], dtype=int32), array([[[252,  23]],
#
#        [[253,  23]],
#
#        [[254,  24]],
#
#        [[252,  26]],
#
#        [[251,  26]],
#
#        [[250,  25]]], dtype=int32), array([[[256,  20]],
#
#        [[257,  20]],
#
#        [[258,  21]],
#
#        [[255,  24]],
#
#        [[254,  24]],
#
#        [[253,  23]]], dtype=int32), array([[[257,  20]],
#
#        [[258,  19]],
#
#        [[259,  19]],
#
#        [[260,  20]],
#
#        [[259,  21]],
#
#        [[258,  21]]], dtype=int32), array([[[261,  17]],
#
#        [[262,  17]],
#
#        [[263,  18]],
#
#        [[261,  20]],
#
#        [[260,  20]],
#
#        [[259,  19]]], dtype=int32), array([[[263,  17]],
#
#        [[264,  16]],
#
#        [[265,  16]],
#
#        [[266,  17]],
#
#        [[265,  18]],
#
#        [[264,  18]]], dtype=int32), array([[[265,  16]],
#
#        [[266,  15]],
#
#        [[267,  15]],
#
#        [[268,  16]],
#
#        [[267,  17]],
#
#        [[266,  17]]], dtype=int32), array([[[267,  15]],
#
#        [[268,  14]],
#
#        [[270,  14]],
#
#        [[271,  15]],
#
#        [[270,  16]],
#
#        [[268,  16]]], dtype=int32), array([[[303,  14]],
#
#        [[304,  13]],
#
#        [[305,  14]],
#
#        [[304,  15]]], dtype=int32), array([[[270,  14]],
#
#        [[271,  13]],
#
#        [[273,  13]],
#
#        [[274,  14]],
#
#        [[273,  15]],
#
#        [[271,  15]]], dtype=int32), array([[[298,  13]],
#
#        [[299,  12]],
#
#        [[300,  13]],
#
#        [[299,  14]]], dtype=int32), array([[[274,  13]],
#
#        [[275,  12]],
#
#        [[279,  12]],
#
#        [[280,  13]],
#
#        [[279,  14]],
#
#        [[275,  14]]], dtype=int32), array([[[289,  12]],
#
#        [[290,  11]],
#
#        [[294,  11]],
#
#        [[295,  12]],
#
#        [[294,  13]],
#
#        [[290,  13]]], dtype=int32), array([[[287,  12]],
#
#        [[288,  11]],
#
#        [[289,  12]],
#
#        [[288,  13]]], dtype=int32), array([[[279,  12]],
#
#        [[280,  11]],
#
#        [[286,  11]],
#
#        [[287,  12]],
#
#        [[286,  13]],
#
#        [[280,  13]]], dtype=int32)]

# %%
contour_im = cv.drawContours(im, contours, -1, (0,255,0), 3)
Image.fromarray(contour_im)
# Out:
# <PIL.Image.Image image mode=RGB size=600x442 at 0x7F9A20C41978>
